# %%
from selenium import webdriver
from bs4 import BeautifulSoup as bs 
import requests
import shutil
import time 
import random


#use selenium to get full source code in img
driver = webdriver.Firefox()
driver.get("http://www.comicvip.com/show/cool-103.html?ch=796-1")

#get the hole page at one chapter
soup0 = driver.page_source
soup0 = bs(soup0)
pagenum = soup0.select('#pagenum')[0].text
page = pagenum.split('/')[1]

fp = page.strip(u'\u9801')
fp = int(fp)


#start to get comic by loop
for i in range (1,fp+1):
    
    driver.implicitly_wait(5) # seconds
    driver.get("http://www.comicvip.com/show/cool-103.html?ch=796-{}".format(i))
    soup=bs(driver.page_source)
    
    soup2 = soup.select('#TheImg')[0].get('src')
    #Making a fake headers by loop because the "Referer" will change by page.  
    headers = {
    'Accept':'image/webp,image/*,*/*;q=0.8',
    'Accept-Encoding':'gzip, deflate, sdch',
    'Accept-Language':'zh-TW,zh;q=0.8,en-US;q=0.6,en;q=0.4',
    'Connection':'keep-alive',
    'Host':'img3.6comic.com:99',
    'Referer':'http://www.comicvip.com/show/cool-103.html?ch=796-'+str(i),
    'User-Agent':'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/45.0.2454.85 Safari/537.36' 
    }
    response = requests.get(soup2, headers = headers, stream=True ,timeout=5)
    with open('E:/comic/0{}.jpg'.format(i), 'wb') as f:
        shutil.copyfileobj(response.raw, f)
        print 'E:/comic/0{}.jpg'.format(i)   
    response.close()
    del response
    ran = int(random.random()*5)+1  ## random second to gentle crawl I don't want to make the website shutdown
    print 'Random sleep time , this loop is going to sleep ' + str(ran) + ' seconds'
    time.sleep(ran)
print '------------------------------------------------'
print 'Downloads are all Finished, congratulations!'

driver.close()

# %%
from selenium import webdriver
from bs4 import BeautifulSoup as bs 
import requests
import shutil
import time 
import random


#use selenium to get full source code in img
driver = driver = webdriver.PhantomJS(executable_path='E:/phantomjs/bin/phantomjs.exe')
driver.get("http://www.comicvip.com/show/cool-103.html?ch=796-1")
soup0 = driver.page_source
soup0 = bs(soup0)

# %%
d=soup0.select('a b')[2].text
print d.split(' ')[1]

# %%
from selenium import webdriver
from bs4 import BeautifulSoup as bs 
import requests
import shutil
import time 
import random


#use selenium to get full source code in img
driver= webdriver.PhantomJS(executable_path='E:/phantomjs/bin/')
driver.get("http://www.comicvip.com/show/cool-103.html?ch=796-1")

#get the hole page at one chapter
soup0 = driver.page_source
soup0 = bs(soup0)
pagenum = soup0.select('#pagenum')[0].text
page = pagenum.split('/')[1]

fp = page.strip(u'\u9801')
fp = int(fp)
driver.close()

#start to get comic by loop
for i in range (1,fp+1):
    driver2 = webdriver.Firefox()
    driver2.implicitly_wait(5) # seconds
    driver2.get("http://www.comicvip.com/show/cool-103.html?ch=796-{}".format(i))
    soup=bs(driver2.page_source)
    driver2.close()
    soup2 = soup.select('#TheImg')[0].get('src')
    #Making a fake headers by loop because the "Referer" will change by page.  
    headers = {
    'Accept':'image/webp,image/*,*/*;q=0.8',
    'Accept-Encoding':'gzip, deflate, sdch',
    'Accept-Language':'zh-TW,zh;q=0.8,en-US;q=0.6,en;q=0.4',
    'Connection':'keep-alive',
    'Host':'img3.6comic.com:99',
    'Referer':'http://www.comicvip.com/show/cool-103.html?ch=796-'+str(i),
    'User-Agent':'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/45.0.2454.85 Safari/537.36' 
    }
    response = requests.get(soup2, headers = headers, stream=True ,timeout=5)
    with open('D:/comic/0{}.jpg'.format(i), 'wb') as f:
        shutil.copyfileobj(response.raw, f)
        print 'D:/comic/0{}.jpg'.format(i)   
    response.close()
    del response
    ran = int(random.random()*5)+1  ## random second to gentle crawl I don't want to make the website shutdown
    print 'Random sleep time , this loop is going to sleep ' + str(ran) + ' seconds'
    time.sleep(ran)
print '------------------------------------------------'
print 'Downloads are all Finished, congratulations!'

# %%
# phantom JS for 471 onepeace
from selenium import webdriver
from bs4 import BeautifulSoup as bs 
import requests
import shutil
import time 
import random
import os

#use selenium to get full source code for the new page
driver = webdriver.PhantomJS(executable_path='E:/phantomjs/bin/phantomjs.exe')
driver.headers = {'ser-Agent': 'User-Agent:Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/45.0.2454.93 Safari/537.36'}
driver.get("http://www.comicvip.com/show/cool-103.html?ch=796-1")
soup0 = driver.page_source
soup0 = bs(soup0)
#select the new chapter
chapter=soup0.select('a b')[2].text

newChapter = chapter.split(' ')[1]
#get the link
strChap = 'http://www.comicvip.com/show/cool-103.html?ch='+newChapter+'-'
newChapter = int(newChapter)

#loop for link

newChapter = int(newChapter)
#mk direcotry to put comic chapter
for j in range(484,newChapter+1):
    comicDirPath = 'E:/comic/{}'.format(j) 
    if not os.path.exists(comicDirPath):
        os.mkdir(comicDirPath)
    else: 
        print 'already exist'
    
    strChapj = 'http://www.comicvip.com/show/cool-103.html?ch={}-1'.format(j)
    
    print strChapj + ' is strChapj'
    #use selenium to get full source code in one chapter img
    driver.get(strChapj)

    #get the hole page at one chapter
    soup0 = driver.page_source
    soup0 = bs(soup0)
    pagenum = soup0.select('#pagenum')[0].text
    page = pagenum.split('/')[1]

    fp = page.strip(u'\u9801')
    fp = int(fp)

         #start to get comic by loop
    for i in range (1,fp+1):
        driver.implicitly_wait(2) # seconds
        strChapji='http://www.comicvip.com/show/cool-103.html?ch={}-{}'.format(j,i)
        print strChapji + ' is strChapji'
        driver.get(strChapji)
        soup2=bs(driver.page_source)
        while True:
            try:
                soup2 = soup2.select('#TheImg')[0].get('src')
                print soup2
            
                #Making a fake headers by loop because the "Referer" will change by page.  
                headers = {
                'Accept':'image/webp,image/*,*/*;q=0.8',
                'Accept-Encoding':'gzip, deflate, sdch',
                'Accept-Language':'zh-TW,zh;q=0.8,en-US;q=0.6,en;q=0.4',
                'Connection':'keep-alive',
                'Host':'img3.6comic.com:99',
                'Referer':strChapji+str(i),
                'User-Agent':'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/45.0.2454.85 Safari/537.36' 
                }
                break
            except:
                print 'start sleep 5secs'
                time.sleep(5)  
        while True:
            try:
                response = requests.get(soup2, headers = headers, stream=True ,timeout=5)
                comic= '/0{}.jpg'.format(i)
        
                with open(comicDirPath+comic, 'wb') as f:
                    shutil.copyfileobj(response.raw, f)  
                response.close()
                del response
                break
            except:
                print 'start sleep 5secs'
                time.sleep(5)         
        
        print 'we got ' + comicDirPath+comic
        ran = int(random.random()*2)+1  ## random second to gentle
        print 'random time this loop is ' + str(ran) + ' seconds'
        time.sleep(ran)
driver.close()                
print '------------------------------------------------'
print 'Downloads are all Finished, congratulations!'
# Out:
# http://www.comicvip.com/show/cool-103.html?ch=484-1 is strChapj
# http://www.comicvip.com/show/cool-103.html?ch=484-1 is strChapji
# http://img3.6comic.com:99/2/103/484/001_wkk.jpg
# we got E:/comic/484/01.jpg
# random time this loop is 2 seconds
# http://www.comicvip.com/show/cool-103.html?ch=484-2 is strChapji
# http://img3.6comic.com:99/2/103/484/002_fww.jpg
# we got E:/comic/484/02.jpg
# random time this loop is 2 seconds
# http://www.comicvip.com/show/cool-103.html?ch=484-3 is strChapji
# http://img3.6comic.com:99/2/103/484/003_9j2.jpg
# we got E:/comic/484/03.jpg
# random time this loop is 2 seconds
# http://www.comicvip.com/show/cool-103.html?ch=484
jpg
# random time this loop is 3 seconds
# http://www.comicvip.com/show/cool-103.html?ch=519-8 is strChapji
# http://img3.6comic.com:99/2/103/519/008_gjc.jpg
# we got E:/comic/519/08.jpg
# random time this loop is 1 seconds
# http://www.comicvip.com/show/cool-103.html?ch=519-9 is strChapji
# http://img3.6comic.com:99/2/103/519/009_2xx.jpg
# we got E:/comic/519/09.jpg
# random time this loop is 1 seconds
# http://www.comicvip.com/show/cool-103.html?ch=519-10 is strChapji
# http://img3.6comic.com:99/2/103/519/010_qmt.jpg
# we got E:/comic/519/010.jpg
# random time this loop is 2 seconds
# http://www.comicvip.com/show/cool-103.html?ch=519-11 is strChapji
# http://img3.6comic.com:99/2/103/519/011_eur.jpg
# we got E:/comic/519/011.jpg
# random time this loop is 1 seconds
# http://www.comicvip.com/show/cool-103.html?ch=519-12 is strChapji
# http://img3.6comic.com:99/2/103/519/012_pgn.jpg
# start sleep 5secs
# we got E:/comic/519/012.jpg
# random time this loop is 3 seconds
# http://www.comicvip.com/show/cool-103.html?ch=519-13 is strChapji
# http://img3.6comic.com:99/2/103/519/013_jvj.jpg
# we got E:/comic/519/013.jpg
# random time this loop is 3 seconds
# http://www.comicvip.com/show/cool-103.html?ch=519-14 is strChapji
# http://img3.6comic.com:99/2/103/519/014_wc4.jpg
# we got E:/comic/519/014.jpg
# random time this loop is 3 seconds
# http://www.comicvip.com/show/cool-103.html?ch=519-15 is strChapji
# http://img3.6comic.com:99/2/103/519/015_y9m.jpg
# we got E:/comic/519/015.jpg
# random time this loop is 2 seconds
# http://www.comicvip.com/show/cool-103.html?ch=519-16 is strChapji
# http://img3.6comic.com:99/2/103/519/016_xmn.jpg
# we got E:/comic/519/016.jpg
# random time this loop is 3 seconds
# http://www.comicvip.com/show/cool-103.html?ch=519-17 is strChapji
# http://img3.6comic.com:99/2/103/519/017_gfg.jpg
# we got E:/comic/519/017.jpg
# random time this loop is 3 seconds
# http://www.comicvip.com/show/cool-103.html?ch=519-18 is strChapji
# http://img3.6comic.com:99/2/103/519/018_jc2.jpg
# we got E:/comic/519/018.jpg
# random time this loop is 3 seconds
# http://www.comicvip.com/show/cool-103.html?ch=519-19 is strChapji
# http://img3.6comic.com:99/2/103/519/019_xxq.jpg
# we got E:/comic/519/019.jpg
# random time this loop is 2 seconds
# http://www.comicvip.com/show/cool-103.html?ch=520-1 is strChapj
# http://www.comicvip.com/show/cool-103.html?ch=520-1 is strChapji
# http://img3.6comic.com:99/2/103/520/001_fxh.jpg
# we got E:/comic/520/01.jpg
# random time this loop is 2 seconds
# http://www.comicvip.com/show/cool-103.html?ch=520-2 is strChapji
# http://img3.6comic.com:99/2/103/520/002_b7h.jpg
# we got E:/comic/520/02.jpg
# random time this loop is 1 seconds
# http://www.comicvip.com/show/cool-103.html?ch=520-3 is strChapji
# http://img3.6comic.com:99/2/103/520/003_7mk.jpg
# we got E:/comic/520/03.jpg
# random time this loop is 1 seconds
# http://www.comicvip.com/show/cool-103.html?ch=520-4 is strChapji
# http://img3.6comic.com:99/2/103/520/004_5w4.jpg
# we got E:/comic/520/04.jpg
# random time this loop is 3 seconds
# http://www.comicvip.com/show/cool-103.html?ch=520-5 is strChapji
# http://img3.6comic.com:99/2/103/520/005_qr4.jpg
# we got E:/comic/520/05.jpg
# random time this loop is 3 seconds
# http://www.comicvip.com/show/cool-103.html?ch=520-6 is strChapji
# http://img3.6comic.com:99/2/103/520/006_qex.jpg
# we got E:/comic/520/06.jpg
# random time this loop is 2 seconds
# http://www.comicvip.com/show/cool-103.html?ch=520-7 is strChapji
# http://img3.6comic.com:99/2/103/520/007_h9b.jpg
# start sleep 5secs
# we got E:/comic/520/07.jpg
# random time this loop is 3 seconds
# http://www.comicvip.com/show/cool-103.html?ch=520-8 is strChapji
# http://img3.6comic.com:99/2/103/520/008_bjr.jpg
# we got E:/comic/520/08.jpg
# random time this loop is 3 seconds
# http://www.comicvip.com/show/cool-103.html?ch=520-9 is strChapji
# http://img3.6comic.com:99/2/103/520/009_qxx.jpg
# we got E:/comic/520/09.jpg
# random time this loop is 1 seconds
# http://www.comicvip.com/show/cool-103.html?ch=520-10 is strChapji
# http://img3.6comic.com:99/2/103/520/010_hh9.jpg
# we got E:/comic/520/010.jpg
# random time this loop is 1 seconds
# http://www.comicvip.com/show/cool-103.html?ch=520-11 is strChapji
# http://img3.6comic.com:99/2/103/520/011_xhb.jpg
# we got E:/comic/520/011.jpg
# random time this loop is 2 seconds
# http://www.comicvip.com/show/cool-103.html?ch=520-12 is strChapji
# http://img3.6comic.com:99/2/103/520/012_7h7.jpg
# we got E:/comic/520/012.jpg
# random time this loop is 3 seconds
# http://www.comicvip.com/show/cool-103.html?ch=520-13 is strChapji
# http://img3.6comic.com:99/2/103/520/013_mk5.jpg
# we got E:/comic/520/013.jpg
# random time this loop is 3 seconds
# http://www.comicvip.com/show/cool-103.html?ch=520-14 is strChapji
# http://img3.6comic.com:99/2/103/520/014_w4q.jpg
# we got E:/comic/520/014.jpg
# random time this loop is 1 seconds
# http://www.comicvip.com/show/cool-103.html?ch=520-15 is strChapji
# http://img3.6comic.com:99/2/103/520/015_r4q.jpg
# we got E:/comic/520/015.jpg
# random time this loop is 1 seconds
# http://www.comicvip.com/show/cool-103.html?ch=520-16 is strChapji
# http://img3.6comic.com:99/2/103/520/016_exh.jpg
# we got E:/comic/520/016.jpg
# random time this loop is 1 seconds
# http://www.comicvip.com/show/cool-103.html?ch=520-17 is strChapji
# http://img3.6comic.com:99/2/103/520/017_9bb.jpg
# we got E:/comic/520/017.jpg
# random time this loop is 1 seconds
# http://www.comicvip.com/show/cool-103.html?ch=520-18 is strChapji
# http://img3.6comic.com:99/2/103/520/018_jrq.jpg
# we got E:/comic/520/018.jpg
# random time this loop is 3 seconds
# http://www.comicvip.com/show/cool-103.html?ch=520-19 is strChapji
# http://img3.6comic.com:99/2/103/520/019_xxh.jpg
# we got E:/comic/520/019.jpg
# random time this loop is 3 seconds
# http://www.comicvip.com/show/cool-103.html?ch=520-20 is strChapji
# http://img3.6comic.com:99/2/103/520/020_h95.jpg
# we got E:/comic/520/020.jpg
# random time this loop is 2 seconds
# http://www.comicvip.com/show/cool-103.html?ch=521-1 is strChapj
# http://www.comicvip.com/show/cool-103.html?ch=521-1 is strChapji
# http://img3.6comic.com:99/2/103/521/001_nud.jpg
# start sleep 5secs
# we got E:/comic/521/01.jpg
# random time this loop is 2 seconds
# http://www.comicvip.com/show/cool-103.html?ch=521-2 is strChapji
# http://img3.6comic.com:99/2/103/521/002_msw.jpg
# we got E:/comic/521/02.jpg
# random time this loop is 2 seconds
# http://www.comicvip.com/show/cool-103.html?ch=521-3 is strChapji
# http://img3.6comic.com:99/2/103/521/003_mwq.jpg
# we got E:/comic/521/03.jpg
# random time this loop is 1 seconds
# http://www.comicvip.com/show/cool-103.html?ch=521-4 is strChapji
# http://img3.6comic.com:99/2/103/521/004_6vx.jpg
# we got E:/comic/521/04.jpg
# random time this loop is 3 seconds
# http://www.comicvip.com/show/cool-103.html?ch=521-5 is strChapji
# http://img3.6comic.com:99/2/103/521/005_sap.jpg
# we got E:/comic/521/05.jpg
# random time this loop is 3 seconds
# http://www.comicvip.com/show/cool-103.html?ch=521-6 is strChapji
# http://img3.6comic.com:99/2/103/521/006_u5u.jpg
# we got E:/comic/521/06.jpg
# random time this loop is 3 seconds
# http://www.comicvip.com/show/cool-103.html?ch=521-7 is strChapji
# http://img3.6comic.com:99/2/103/521/007_k7c.jpg
# we got E:/comic/521/07.jpg
# random time this loop is 1 seconds
# http://www.comicvip.com/show/cool-103.html?ch=521-8 is strChapji
# http://img3.6comic.com:99/2/103/521/008_767.jpg
# we got E:/comic/521/08.jpg
# random time this loop is 3 seconds
# http://www.comicvip.com/show/cool-103.html?ch=521-9 is strChapji
# http://img3.6comic.com:99/2/103/521/009_weg.jpg
# we got E:/comic/521/09.jpg
# random time this loop is 3 seconds
# http://www.comicvip.com/show/cool-103.html?ch=521-10 is strChapji
# http://img3.6comic.com:99/2/103/521/010_qx2.jpg
# we got E:/comic/521/010.jpg
# random time this loop is 2 seconds
# http://www.comicvip.com/show/cool-103.html?ch=521-11 is strChapji
# http://img3.6comic.com:99/2/103/521/011_udm.jpg
# we got E:/comic/521/011.jpg
# random time this loop is 2 seconds
# http://www.comicvip.com/show/cool-103.html?ch=521-12 is strChapji
# http://img3.6comic.com:99/2/103/521/012_swm.jpg
# we got E:/comic/521/012.jpg
# random time this loop is 3 seconds
# http://www.comicvip.com/show/cool-103.html?ch=521-13 is strChapji
# http://img3.6comic.com:99/2/103/521/013_wq6.jpg
# start sleep 5secs
# we got E:/comic/521/013.jpg
# random time this loop is 2 seconds
# http://www.comicvip.com/show/cool-103.html?ch=521-14 is strChapji
# http://img3.6comic.com:99/2/103/521/014_vxs.jpg
# we got E:/comic/521/014.jpg
# random time this loop is 2 seconds
# http://www.comicvip.com/show/cool-103.html?ch=521-15 is strChapji
# http://img3.6comic.com:99/2/103/521/015_apu.jpg
# we got E:/comic/521/015.jpg
# random time this loop is 2 seconds
# http://www.comicvip.com/show/cool-103.html?ch=521-16 is strChapji
# http://img3.6comic.com:99/2/103/521/016_5uk.jpg
# we got E:/comic/521/016.jpg
# random time this loop is 3 seconds
# http://www.comicvip.com/show/cool-103.html?ch=521-17 is strChapji
# http://img3.6comic.com:99/2/103/521/017_7c7.jpg
# we got E:/comic/521/017.jpg
# random time this loop is 1 seconds
# http://www.comicvip.com/show/cool-103.html?ch=521-18 is strChapji
# http://img3.6comic.com:99/2/103/521/018_67w.jpg
# we got E:/comic/521/018.jpg
# random time this loop is 3 seconds
# http://www.comicvip.com/show/cool-103.html?ch=521-19 is strChapji
# http://img3.6comic.com:99/2/103/521/019_egq.jpg
# we got E:/comic/521/019.jpg
# random time this loop is 2 seconds
# http://www.comicvip.com/show/cool-103.html?ch=522-1 is strChapj
# http://www.comicvip.com/show/cool-103.html?ch=522-1 is strChapji
# http://img3.6comic.com:99/2/103/522/001_uyn.jpg
# we got E:/comic/522/01.jpg
# random time this loop is 2 seconds
# http://www.comicvip.com/show/cool-103.html?ch=522-2 is strChapji
# http://img3.6comic.com:99/2/103/522/002_q8u.jpg
# we got E:/comic/522/02.jpg
# random time this loop is 1 seconds
# http://www.comicvip.com/show/cool-103.html?ch=522-3 is strChapji
# http://img3.6comic.com:99/2/103/522/003_bua.jpg
# we got E:/comic/522/03.jpg
# random time this loop is 2 seconds
# http://www.comicvip.com/show/cool-103.html?ch=522-4 is strChapji

# %%
type(chapter)

# %%
import os
if not os.path.exists('E:\comic\ddd'):
    os.mkdir('E:\comic\ddd')
else: 
    print 'already exist'

# %%
chapter=soup0.select('a b')[2].text

newChapter = chapter.split(' ')[1]

strChap = 'http://www.comicvip.com/show/cool-103.html?ch='+newChapter+'-'
print strChap

# %%
type (int(newChapter))

# %%
newChapter = int(newChapter)
#mk direcotry to put comic chapter
for i in range(1,newChapter+1):
    comicDirPath = 'E:/comic/' + str(i)
    if not os.path.exists(comicDirPath):
        os.mkdir(comicDirPath)
    else: 
        print 'already exist'

# %%
newChapter = int(newChapter)
#mk direcotry to put comic chapter
for i in range(1,newChapter+1):
    comic= '0{}.jpg'.format(i)
    print comic

# %%
#V2
# phantom JS for 471 onepeace
from selenium import webdriver
from bs4 import BeautifulSoup as bs 
import requests
import shutil
import time 
import random
import os

#use selenium to get full source code for the new page
driver = webdriver.PhantomJS(executable_path='E:/phantomjs/bin/phantomjs.exe')
driver.headers = {'ser-Agent': 'User-Agent:Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/45.0.2454.93 Safari/537.36'}
driver.get("http://www.comicvip.com/show/cool-103.html?ch=796-1")
soup0 = driver.page_source
soup0 = bs(soup0)
#select the new chapter
chapter=soup0.select('a b')[2].text

newChapter = chapter.split(' ')[1]
#get the link
strChap = 'http://www.comicvip.com/show/cool-103.html?ch='+newChapter+'-'
newChapter = int(newChapter)

#loop for link

newChapter = int(newChapter)
#mk direcotry to put comic chapter
for j in range(484,newChapter+1):
    comicDirPath = 'E:/comic/{}'.format(j) 
    if not os.path.exists(comicDirPath):
        os.mkdir(comicDirPath)
    else: 
        print 'already exist'
    
    strChapj = 'http://www.comicvip.com/show/cool-103.html?ch={}-1'.format(j)
    
    print strChapj + ' is strChapj'
    #use selenium to get full source code in one chapter img
    driver.get(strChapj)

    #get the hole page at one chapter
    soup0 = driver.page_source
    soup0 = bs(soup0)
    pagenum = soup0.select('#pagenum')[0].text
    page = pagenum.split('/')[1]

    fp = page.strip(u'\u9801')
    fp = int(fp)

         #start to get comic by loop
    for i in range (1,fp+1):
        driver.implicitly_wait(2) # seconds
        strChapji='http://www.comicvip.com/show/cool-103.html?ch={}-{}'.format(j,i)
        driver.get(strChapji)
        soup2=bs(driver.page_source)
        while True:
            try:
                soup2 = soup2.select('#TheImg')[0].get('src')
                #Making a fake headers by loop because the "Referer" will change by page.  
                headers = {
                'Accept':'image/webp,image/*,*/*;q=0.8',
                'Accept-Encoding':'gzip, deflate, sdch',
                'Accept-Language':'zh-TW,zh;q=0.8,en-US;q=0.6,en;q=0.4',
                'Connection':'keep-alive',
                'Host':'img3.6comic.com:99',
                'Referer':strChapji+str(i),
                'User-Agent':'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/45.0.2454.85 Safari/537.36' 
                }
                break
            except:
                print 'start sleep 5secs'
                time.sleep(5)  
        while True:
            try:
                response = requests.get(soup2, headers = headers, stream=True ,timeout=5)
                comic= '/0{}.jpg'.format(i)
        
                with open(comicDirPath+comic, 'wb') as f:
                    shutil.copyfileobj(response.raw, f)  
                response.close()
                del response
                break
            except:
                print 'start sleep 5secs'
                time.sleep(5)         
        
        ran = int(random.random()*2)+1  ## random second to gentle
        print 'random time this loop is ' + str(ran) + ' seconds'
        time.sleep(ran)
    print 'the' +   str(j) + "is complete"  
driver.close()                
print '------------------------------------------------'
print 'Downloads are all Finished, congratulations!'
