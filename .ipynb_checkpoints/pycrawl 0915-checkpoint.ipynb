# %%
import requests
payload = {
    'method':'search',
'searchMethod':'true',
'searchTarget':'ATM',
'orgName':'',
'orgId':'',
'hid_1':'1',
'tenderName':'',
'tenderId':'',
'tenderStatus':'4,5,21,29',
'tenderWay':'',
'awardAnnounceStartDate':'104/09/15',
'awardAnnounceEndDate':'104/09/15',
'proctrgCate':'',
'tenderRange':'',
'minBudget':'',
'maxBudget':'',
'item':'',
'hid_2':'1',
'gottenVendorName':'',
'gottenVendorId':'',
'hid_3':'1',
'submitVendorName':'',
'submitVendorId':'',
'location':'',
'priorityCate':'',
'isReConstruct':'',
'btnQuery':'查詢'   
}
rs = requests.session()
res = requests.post('http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance',data = payload)

from bs4 import BeautifulSoup as bs
soup = bs(res.text)

# %%
from math import ceil
rec_number = (soup.select('.T11b')[0].text)
page_number =  int(ceil(float(rec_number)/100))
print page_number

# %%
rs = requests.session()
res = rs.post('http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance',data = payload)
page_format = 'http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance&\
searchTarget=ATM&method=search&isSpdt=&pageIndex={0}'
for page in range(1,page_number + 1 ):
    print page_format.format(page)

# %%
rs = requests.session()
res = rs.post('http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance',data = payload)
page_format = 'http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance&\
searchTarget=ATM&method=search&isSpdt=&pageIndex={0}'
web = rs.get(page_format.format(6))

from bs4 import BeautifulSoup as bs
bid_soup = bs(web.text)
bid_table = bid_soup.select('#print_area')[0]
bid_rows = bid_table.select('tr')[1:-1]



'''
for page in range(1,page_number + 1 ):
    pageurl = page_format.format(page)
    res2 = rs.get(pageurl)
    print res2
    print res2.url
'''

# %%
import urlparse

#for bid_row in bid_rows:
#    print 'http://web.pcc.gov.tw/tps' + bid_row.select('a')[0]['href'][2:]

f = open('bid_list.txt', 'w')  
for bid_row in bid_rows: 
    link_href =  urlparse.urljoin(res.url , \
                           bid_row.select('a')[0]['href'])
    f.write(link_href + '\n')
f.close()

# %%
#full version

import requests
payload = {
    'method':'search',
'searchMethod':'true',
'searchTarget':'ATM',
'orgName':'',
'orgId':'',
'hid_1':'1',
'tenderName':'',
'tenderId':'',
'tenderStatus':'4,5,21,29',
'tenderWay':'',
'awardAnnounceStartDate':'104/09/15',
'awardAnnounceEndDate':'104/09/15',
'proctrgCate':'',
'tenderRange':'',
'minBudget':'',
'maxBudget':'',
'item':'',
'hid_2':'1',
'gottenVendorName':'',
'gottenVendorId':'',
'hid_3':'1',
'submitVendorName':'',
'submitVendorId':'',
'location':'',
'priorityCate':'',
'isReConstruct':'',
'btnQuery':'查詢'   
}
# get the session
rs = requests.session()
res = rs.post('http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance',data = payload)


# get the page number
from bs4 import BeautifulSoup as bs
soup = bs(res.text)
from math import ceil
rec_number = (soup.select('.T11b')[0].text)
page_number =  int(ceil(float(rec_number)/100))

# open a file
f = open('bid_list.txt', 'w')

# format
page_format = 'http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance&\
searchTarget=ATM&method=search&isSpdt=&pageIndex={}'

# page iteration

from bs4 import BeautifulSoup as bs
import urlparse
for page in range(1,page_number + 1 ):
    pageurl = page_format.format(page)
    res2 = rs.get(pageurl)
    bid_soup = bs(res2.text)
    bid_table = bid_soup.select('#print_area')[0]
    bid_rows = bid_table.select('tr')[1:-1]   
    for bid_row in bid_rows: 
        link_href = urlparse.urljoin(res.url , \
                                     bid_row.select('a')[0]['href'])
        f.write(link_href + '\n')
f.close()

# %%
#test
print len([f for f in open('bid_list.txt', 'r')])
#test2
full = open('bid_list.txt', 'r')
cnt = 0
for f in full:
    cnt +=1
print cnt
full.close()

#test3

full = open('bid_list.txt', 'r')
cnt = 0
for idt,line in enumerate(full):
    cnt = idt
print cnt + 1
#check the same
rec_number = int(rec_number)
if rec_number ==cnt+1:
    print 'download successfully'
# Out:
# 579
# 579
# 579
# download successfully

# %%
from bs4 import BeautifulSoup as bs
#research the key
bid_url = open('bid_list.txt','r')
headers ={
 'Accept':'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
'Accept-Encoding':'gzip, deflate, sdch',
'Accept-Language':'zh-TW,zh;q=0.8,en-US;q=0.6,en;q=0.4',
'Cache-Control':'max-age=0',
'Connection':'keep-alive',
'Cookie':'ccsession=201509151127266601000a2b508171; ccguid=201509151127266601000a2b508171; JSESSIONID=0000pi52yffFHj17Ve5I1hGrDtL:14adnh85p; cookiesession1=5D83A987UXHFDHKLQ3MJNOPQOZQ02F1F; NSC_xfc_qfstjtufodf=ffffffff09081f7745525d5f4f58455e445a4a423660',
'Host':'web.pcc.gov.tw',
'Upgrade-Insecure-Requests':'1'
} 
bid_detail = open("bid_detail.txt",'w') 
url = bid_url.readline().strip()   #strip()必加 去空白
#http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51642101&tenderCaseNo=1040828

request_get = requests.get(url,headers=headers)
response = request_get.text.encode('utf-8')
soup = bs(response)
printarea = soup.select('#printArea')[0]
bid_detail.close()
# Out:
# <div class="main" id="printArea">
#
#               	﻿﻿﻿﻿﻿<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN">
#
# <head>
# <link href="/tps/styles/text.css" rel="stylesheet" type="text/css"/>
# <link href="/tps/styles/css.css" rel="stylesheet" type="text/css"/>
# <link href="/tps/styles/chtd_tab.css" rel="stylesheet" type="text/css"/>
# <link href="/tps/styles/chtd.css" rel="stylesheet" type="text/css"/>
# <style>
# td {align: left;}
# </style>
# </head>
# <script>
# $jq(document).ready(function(){
# 	popWatermark();
# });
#
# function openEditScreen(editUrl){
#     window.open(encodeURI(editUrl));
#     unblock();
# }
#
# function popWatermark(){
# 	        var msgTop = 50;
# 	        var msgLeft = 500;
#
# 	        try{
# 	        	msgTop = $jq("#printArea").position().top+50;
# 	        	msgLeft = $jq("#printArea").position().left +$jq("#printArea").width()/2 +50;
# 			}catch(e) {}
#
# 			$jq("#hidden_message_id")
# 	        .css({
# 	            fontSize: "100px", //watermark font size
# 	            color: "brown", //watermark color
# 	            fontWeight: "bolder", //watermark font weight
# 	            fontFamily: "verdana", //watermark font family
# 	            position: "absolute", //watermark position 必須為 "absolute"
# 	            width: "100px", //watermark div width
# 	            top: msgTop, //watermark position top
# 	            left: msgLeft //watermark position left
# 	        })
# 	        .fadeTo("fast",0.3); //watermark 透明度
# }
#
# function popWatermark2(){
# 	        var msgTop = 200;
# 	        var msgLeft = 500;
# 			$jq("#hidden_message_id")
# 	        .css({
# 	            fontSize: "120px", //watermark font size
# 	            color: "brown", //watermark color
# 	            fontWeight: "bolder", //watermark font weight
# 	            fontFamily: "verdana", //watermark font family
# 	            position: "absolute", //watermark position 必須為 "absolute"
# 	            width: "120px", //watermark div width
# 	            top: msgTop, //watermark position top
# 	            left: msgLeft //watermark position left
# 	        })
# 	        .fadeTo("fast",0.3); //watermark 透明度
# }
#
# //共同供應契約顯示得標廠商清單
# function printBidder(pkItem){
# 		//alert(pkItem);
#
# 		    var popupWindow = window.open('/tps/main/pms/tps/atm/atmAwardAction.do?method=qryCppObtain&pkAtmMain=51642101&pkAtmAwardItem='+pkItem+'&tenderCaseNo=1040828','showBidder','status=yes,toolbar=no,menubar=no,location=no,resizable=yes,scrollbars=yes,width=750,height=500',true);
#
# }
# </script>
# <table border="1" cellpadding="0" cellspacing="0" class="table_block tender_table" width="100%">
# <caption style="display:none">
# <center><font size="5">定期彙送</font></center>
# <div align="center" id="printAwardDate" style="display:block">公告日:104/09/15</div>
# </caption>
# <tbody>
# <tr>
# <td align="center" colspan="4" style="border:1px solid #FFFFFF;">
# <center><h1>定期彙送</h1></center>
# <div align="center" id="printAwardDate" style="display:block"><h3>公告日:104/09/15</h3></div>
# <div class="remind_msg"></div>
# </td>
# </tr>
# <!-- delimiter 機關資料 Start -->
# <tr class="award_table_tr_1">
# <td align="center" bgcolor="#89C0C7" class="style1" rowspan="8" valign="middle" width="38">
# <span class="newstop">機<br/>關<br/>資<br/>料</span>
# </td>
# </tr>
# <tr class="award_table_tr_1">
# <th align="left" bgcolor="#DAEBED" class="T11b" valign="middle" width="200">機關代碼</th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
# 			26674374
# 		</td>
# </tr>
# <tr class="award_table_tr_1">
# <th align="left" bgcolor="#DAEBED" class="T11b" valign="middle" width="200">機關名稱</th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
# 			新北市立永和幼兒園
# 		</td>
# </tr>
# <tr class="award_table_tr_1">
# <th align="left" bgcolor="#DAEBED" class="T11b" valign="middle" width="200">單位名稱</th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#             新北市立永和幼兒園
#         </td>
# </tr>
# <tr class="award_table_tr_1">
# <th align="left" bgcolor="#DAEBED" class="T11b" valign="middle" width="200">機關地址</th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#
#
#
#
#
#
#
#
#
#
#                               234新北市永和區民權路60號3樓
# 		</td>
# </tr>
# <tr class="award_table_tr_1">
# <th align="left" bgcolor="#DAEBED" class="T11b" valign="middle" width="200">聯絡人</th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#
#
# 			謝志偉
# 	</td>
# </tr>
# <tr class="award_table_tr_1">
# <th align="left" bgcolor="#DAEBED" class="T11b" valign="middle" width="200">聯絡電話</th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#
#
#                               (02)29483199 分機 16
#                           </td>
# </tr>
# <tr class="award_table_tr_1">
# <th align="left" bgcolor="#DAEBED" class="T11b" style="height: 25px" valign="middle" width="200">傳真號碼</th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#
#
#                               (02)29489099
#                           </td>
# </tr>
# <!-- delimiter 機關資料 End -->
# <!-- delimiter 已公告/採購資料 Start -->
# <tr class="award_table_tr_2">
# <td align="center" bgcolor="#FCD847" class="form_head" rowspan="30 " valign="middle" width="38">
# <span class="newstop">已<br/>公<br/>告<br/>資<br/>料</span>
# </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">標案案號</th>
# <td bgcolor="#EFF1F1" class="newstop">
# 			1040828
# 		</td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">招標方式</th>
# <td bgcolor="#EFF1F1" class="newstop">
# 			公開取得報價單或企劃書
# 			<div class="remind_msg">
# </div>
# </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">決標方式</th>
# <td bgcolor="#EFF1F1" class="newstop">
# 			最低標
# 			<div class="remind_msg">
# </div>
# </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">
# 	    	是否依政府採購法施行<br>細則第64條之2辦理
# 		</br></th>
# <td bgcolor="#EFF1F1" class="newstop">
# 			否
# 			<div class="remind_msg">
# </div>
# </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">新增公告傳輸次數</th>
# <td bgcolor="#EFF1F1" class="newstop">
# 			01
# 		</td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">是否依據採購法第106條第1項第1款辦理</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
# 			否
#         </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">標案名稱</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
# 			本園104年度吊掛隱藏式冷氣機採購案
# 		</td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">決標資料類別</th>
# <td bgcolor="#EFF1F1" class="newstop">
# 			定期彙送
# 		</td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">是否屬共同供應契約採購</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
#
#
#
# 			否
#
# 		</td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">是否屬二以上機關之聯合採購(不適用共同供應契約規定)</th>
# <td bgcolor="#EFF1F1" class="newstop">
# 			否
#
# 		</td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">是否複數決標</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
#
#
#
# 			否
#
# 		</td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">是否共同投標</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
#
#
#
# 		否
# 		</td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">標的分類</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
#
#
#
#
# 							&lt;財物類&gt;
#                             4391
#                             氣體產生器; 蒸餾設備; 冷凍及空調設備; 過濾機具
#
# 		</td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">是否屬統包</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
#
#
#
#         	否
#          </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">是否應依公共工程專業技師簽證規則實施技師簽證</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
#
#
#
#
#
#
#
#
#
#         	否
#
#         </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">開標時間</th>
# <td bgcolor="#EFF1F1" class="newstop">
#         	104/09/11 10:00
#         </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">原公告日期</th>
# <td bgcolor="#EFF1F1" class="newstop">
#         	104/09/01
#
#         	<span>　　<span class="remind_msg">原公告日期係指最近1次招標公告或更正日期</span></span>
# </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">採購金額級距</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
#
#
#
#
#
#         	未達公告金額
# 			<div class="remind_msg">
# </div>
# </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">辦理方式</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
#
#
#
#
# 			自辦
# 		</td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">預算金額是否公開</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
#
#
#
# 			是
#
# 		</td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">預算金額</th>
# <td bgcolor="#EFF1F1" class="newstop">
# 			849,840元
#
#
#
#
#
#
#
#
#                     </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">是否受機關補助</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
#
#
#
# 			是
# 		</td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200"> </th>
# <td bgcolor="#EFF1F1" class="newstop" colspan="2">
# <table bgcolor="#FFCC66" border="0" style="vertical-align: middle; text-align: center" summary="*">
# <tr align="center" id="grant_org_item" valign="middle">
# <td align="center" bgcolor="#FFFF99" class="workstop" style="text-align: center" valign="middle" width="50">項次</td>
# <td align="center" bgcolor="#FFFF99" class="workstop" valign="middle" width="150">補助機關代碼</td>
# <td align="center" bgcolor="#FFFF99" class="workstop" valign="middle" width="150">補助機關名稱</td>
# <td align="center" bgcolor="#FFFF99" class="workstop" valign="middle" width="180">補助金額</td>
# </tr>
# <tr bgcolor="#FFFFC8">
# <td align="center" bgcolor="#FFFFC8" class="T10" width="50">1</td>
# <td align="center" bgcolor="#FFFFC8" class="T10" width="150">
# 							A.9.3
# 						</td>
# <td align="center" bgcolor="#FFFFC8" class="T10" width="150">
# 							教育部國民及學前教育署
# 						</td>
# <td align="center" bgcolor="#FFFFC8" class="T10" width="180">
# 							680,000元
# 						</td>
# </tr>
# </table>
# </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">履約地點</th>
# <td bgcolor="#EFF1F1" class="newstop">
# 			 新北市(非原住民地區)
#                           </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">履約地點（含地區）</th>
# <td bgcolor="#EFF1F1" class="newstop">
# 	    	新北市－永和區
# 	         </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">是否於招標文件載明優先決標予身心障礙福利機構團體或庇護工場</th>
# <td bgcolor="#EFF1F1" class="newstop">
# 				否
# 			</td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">是否含特別預算</th>
# <td bgcolor="#EFF1F1" class="newstop">
#                               否
#
#
#
# 		</td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">歸屬計畫類別</th>
# <td bgcolor="#EFF1F1" class="newstop">
# 			非屬愛台十二項計畫
# 		</td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">本案採購契約是否採用主管機關訂定之範本</th>
# <td bgcolor="#EFF1F1" class="newstop">
# 			是
#
# 		</td>
# </tr>
# <!-- 不公開於其他機關、廠商端、民眾端及政府採購公報電子版 -->
# <!-- 政府計畫管理資訊網之標案案號有值才顯示，但不公開於廠商端/民眾端及政府採購公報 -->
# <!-- delimiter 已公告/採購資料 End -->
# <!-- delimiter 資訊服務價格 Start -->
# <!-- delimiter 資訊服務價格 End -->
# <!-- delimiter 投標廠商 Start -->
# <tr class="award_table_tr_3">
# <td align="center" bgcolor="#F5BF65" rowspan="2" valign="middle" width="38">
# <span class="newstop">投<br/>標<br/>廠<br/>商</span>
# </td>
# </tr>
# <tr class="award_table_tr_3"><td colspan="3" style="padding-top:0px; padding-bottom:0px; padding-right:0px; padding-left:0px;">
# <table bgcolor="#F5BF65" border="1" bordercolor="#F5BF65" cellpadding="1" cellspacing="1" class="table_block tender_table" height="100%" style="border-collapse:collapse;" summary="*" width="100%">
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">投標廠商家數</th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
# 			13
# 		</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#
#
#
#
#
# 					投標廠商1
#
#
#
#
#
# 		</th>
# <td bgcolor="#EFF1F1" class="newstop" height="25"></td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">　廠商代碼</th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#
#
#
#
#
#
# 						12788968
#
#
#
#
# 		</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">　廠商名稱</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
# 			東軒盟企業有限公司
# 		</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">　是否得標</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
#
#
#
# 	                             否
# 		</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">　組織型態</th>
# <td bgcolor="#EFF1F1" class="newstop" height="7">
# 	    	 公司登記
#
# 	    </td>
# </tr>
# <!-- isObtain -->
# <!-- isNotObtain start -->
# <!-- isNotObtain end -->
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#
#
#
#
#
# 					投標廠商2
#
#
#
#
#
# 		</th>
# <td bgcolor="#EFF1F1" class="newstop" height="25"></td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">　廠商代碼</th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#
#
#
#
#
#
# 						23555804
#
#
#
#
# 		</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">　廠商名稱</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
# 			正東電器有限公司
# 		</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">　是否得標</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
#
#
#
# 	                             否
# 		</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">　組織型態</th>
# <td bgcolor="#EFF1F1" class="newstop" height="7">
# 	    	 公司登記
#
# 	    </td>
# </tr>
# <!-- isObtain -->
# <!-- isNotObtain start -->
# <!-- isNotObtain end -->
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#
#
#
#
#
# 					投標廠商3
#
#
#
#
#
# 		</th>
# <td bgcolor="#EFF1F1" class="newstop" height="25"></td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">　廠商代碼</th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#
#
#
#
#
#
# 						16707235
#
#
#
#
# 		</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">　廠商名稱</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
# 			建丞空調工程股份有限公司
# 		</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">　是否得標</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
#
#
#
# 	                             否
# 		</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">　組織型態</th>
# <td bgcolor="#EFF1F1" class="newstop" height="7">
# 	    	 公司登記
#
# 	    </td>
# </tr>
# <!-- isObtain -->
# <!-- isNotObtain start -->
# <!-- isNotObtain end -->
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#
#
#
#
#
# 					投標廠商4
#
#
#
#
#
# 		</th>
# <td bgcolor="#EFF1F1" class="newstop" height="25"></td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">　廠商代碼</th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#
#
#
#
#
# 						09842067
#
#
#
#
#
# 		</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">　廠商名稱</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
# 			淨寶電器行
# 		</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">　是否得標</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
#
#
#
# 	                             是
# 		</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">　組織型態</th>
# <td bgcolor="#EFF1F1" class="newstop" height="7">
# 	    	 商業登記
#
# 	    </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">　廠商業別</th>
# <td bgcolor="#EFF1F1" class="newstop" height="7">
# 	    	其他
#
# 	    </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">　廠商地址</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
#
#
#
#
#
#
#
#
#
#
# 			320桃園市中壢區水尾里興忠街六六號一樓
# 		</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">　廠商電話</th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#
#
#
# 		(03)
#
#
# 				4558216
# 		</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">　決標金額</th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
# 		719,086元
# 		</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">　得標廠商國別</th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
# 			中華民國(Republic of China (Taiwan))
# 		</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">　是否為中小企業</th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#
#
#
#
#
# 	                             是
# 		</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">　履約起迄日期</th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#
#
# 			104/09/11－104/11/09
# 		</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">　雇用員工總人數是否<br>　超過100人</br></th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#
#
#
#
#
# 	                         否
# 		</td>
# </tr>
# <!-- isEmployeeOver100 -->
# <!-- isObtain -->
# <!-- isNotObtain end -->
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#
#
#
#
#
# 					投標廠商5
#
#
#
#
#
# 		</th>
# <td bgcolor="#EFF1F1" class="newstop" height="25"></td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">　廠商代碼</th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#
#
#
#
#
#
# 						24748323
#
#
#
#
# 		</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">　廠商名稱</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
# 			亨佳空調工程有限公司
# 		</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">　是否得標</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
#
#
#
# 	                             否
# 		</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">　組織型態</th>
# <td bgcolor="#EFF1F1" class="newstop" height="7">
# 	    	 公司登記
#
# 	    </td>
# </tr>
# <!-- isObtain -->
# <!-- isNotObtain start -->
# <!-- isNotObtain end -->
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#
#
#
#
#
# 					投標廠商6
#
#
#
#
#
# 		</th>
# <td bgcolor="#EFF1F1" class="newstop" height="25"></td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">　廠商代碼</th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#
#
#
#
#
#
# 						54695203
#
#
#
#
# 		</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">　廠商名稱</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
# 			有序凍藏設備有限公司
# 		</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">　是否得標</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
#
#
#
# 	                             否
# 		</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">　組織型態</th>
# <td bgcolor="#EFF1F1" class="newstop" height="7">
# 	    	 公司登記
#
# 	    </td>
# </tr>
# <!-- isObtain -->
# <!-- isNotObtain start -->
# <!-- isNotObtain end -->
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#
#
#
#
#
# 					投標廠商7
#
#
#
#
#
# 		</th>
# <td bgcolor="#EFF1F1" class="newstop" height="25"></td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">　廠商代碼</th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#
#
#
#
#
#
# 						00724722
#
#
#
#
# 		</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">　廠商名稱</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
# 			大成電器行
# 		</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">　是否得標</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
#
#
#
# 	                             否
# 		</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">　組織型態</th>
# <td bgcolor="#EFF1F1" class="newstop" height="7">
# 	    	 商業登記
#
# 	    </td>
# </tr>
# <!-- isObtain -->
# <!-- isNotObtain start -->
# <!-- isNotObtain end -->
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#
#
#
#
#
# 					投標廠商8
#
#
#
#
#
# 		</th>
# <td bgcolor="#EFF1F1" class="newstop" height="25"></td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">　廠商代碼</th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#
#
#
#
#
#
# 						99966399
#
#
#
#
# 		</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">　廠商名稱</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
# 			亞瑞司商行
# 		</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">　是否得標</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
#
#
#
# 	                             否
# 		</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">　組織型態</th>
# <td bgcolor="#EFF1F1" class="newstop" height="7">
# 	    	 商業登記
#
# 	    </td>
# </tr>
# <!-- isObtain -->
# <!-- isNotObtain start -->
# <!-- isNotObtain end -->
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#
#
#
#
#
# 					投標廠商9
#
#
#
#
#
# 		</th>
# <td bgcolor="#EFF1F1" class="newstop" height="25"></td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">　廠商代碼</th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#
#
#
#
#
#
# 						28758758
#
#
#
#
# 		</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">　廠商名稱</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
# 			磐固企業有限公司
# 		</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">　是否得標</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
#
#
#
# 	                             否
# 		</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">　組織型態</th>
# <td bgcolor="#EFF1F1" class="newstop" height="7">
# 	    	 公司登記
#
# 	    </td>
# </tr>
# <!-- isObtain -->
# <!-- isNotObtain start -->
# <!-- isNotObtain end -->
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#
#
#
#
#
# 					投標廠商10
#
#
#
#
#
# 		</th>
# <td bgcolor="#EFF1F1" class="newstop" height="25"></td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">　廠商代碼</th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#
#
#
#
#
#
# 						12601231
#
#
#
#
# 		</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">　廠商名稱</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
# 			竑偉企業有限公司
# 		</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">　是否得標</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
#
#
#
# 	                             否
# 		</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">　組織型態</th>
# <td bgcolor="#EFF1F1" class="newstop" height="7">
# 	    	 公司登記
#
# 	    </td>
# </tr>
# <!-- isObtain -->
# <!-- isNotObtain start -->
# <!-- isNotObtain end -->
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#
#
#
#
#
# 					投標廠商11
#
#
#
#
#
# 		</th>
# <td bgcolor="#EFF1F1" class="newstop" height="25"></td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">　廠商代碼</th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#
#
#
#
#
#
# 						89583247
#
#
#
#
# 		</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">　廠商名稱</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
# 			祥慶電氣工程有限公司
# 		</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">　是否得標</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
#
#
#
# 	                             否
# 		</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">　組織型態</th>
# <td bgcolor="#EFF1F1" class="newstop" height="7">
# 	    	 公司登記
#
# 	    </td>
# </tr>
# <!-- isObtain -->
# <!-- isNotObtain start -->
# <!-- isNotObtain end -->
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#
#
#
#
#
# 					投標廠商12
#
#
#
#
#
# 		</th>
# <td bgcolor="#EFF1F1" class="newstop" height="25"></td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">　廠商代碼</th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#
#
#
#
#
#
# 						84768076
#
#
#
#
# 		</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">　廠商名稱</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
# 			鍾鼎電業有限公司
# 		</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">　是否得標</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
#
#
#
# 	                             否
# 		</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">　組織型態</th>
# <td bgcolor="#EFF1F1" class="newstop" height="7">
# 	    	 公司登記
#
# 	    </td>
# </tr>
# <!-- isObtain -->
# <!-- isNotObtain start -->
# <!-- isNotObtain end -->
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#
#
#
#
#
# 					投標廠商13
#
#
#
#
#
# 		</th>
# <td bgcolor="#EFF1F1" class="newstop" height="25"></td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">　廠商代碼</th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#
#
#
#
#
#
# 						36512568
#
#
#
#
# 		</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">　廠商名稱</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
# 			三澤工程股份有限公司
# 		</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">　是否得標</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
#
#
#
# 	                             否
# 		</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">　組織型態</th>
# <td bgcolor="#EFF1F1" class="newstop" height="7">
# 	    	 公司登記
#
# 	    </td>
# </tr>
# <!-- isObtain -->
# <!-- isNotObtain start -->
# <!-- isNotObtain end -->
# </table>
# </td></tr>
# <!-- delimiter 投標廠商 End -->
# <!-- delimiter 簽約廠商 Start -->
# <!-- delimiter 簽約廠商 End -->
# <!-- delimiter 決標品項 Start -->
# <tr class="award_table_tr_4">
# <td align="center" bgcolor="#FF9999" rowspan="2" valign="middle" width="38">
# <span class="newstop">決<br/>標<br/>品<br/>項</span>
# </td>
# </tr>
# <tr class="award_table_tr_4"><td colspan="3" style="padding-top:0px; padding-bottom:0px; padding-right:0px; padding-left:0px;">
# <table bgcolor="#FF9999" border="1" bordercolor="#FF9999" cellpadding="1" cellspacing="1" class="table_block tender_table" height="100%" style="border-collapse:collapse;" summary="*" width="100%">
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">決標品項數</th>
# <td bgcolor="#EFF1F1" class="newstop">
# 				1
# 			</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">第1品項</th>
# <td bgcolor="#EFF1F1" class="newstop"></td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　品項名稱</th>
# <td bgcolor="#EFF1F1" class="newstop">
# 				本園104年度吊掛隱藏式冷氣機採購案
# 			</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　是否以單價及預估需<br>　求數量之乘積決定最<br>　低標</br></br></th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
#
#
#
# 	                             否
# 			</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　得標廠商1</th>
# <td bgcolor="#EFF1F1" class="newstop"></td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　　得標廠商</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
# 				淨寶電器行
# 			</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　　預估需求數量</th>
# <td bgcolor="#EFF1F1" class="newstop">
# 				1
# 			</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　　決標金額
#
# 			</th>
# <td bgcolor="#EFF1F1" class="newstop">
# 				719,086
# 			元</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　　底價金額
#
# 			</th>
# <td bgcolor="#EFF1F1" class="newstop">
# 			750,000
# 			元</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　　原產地國別</th>
# <td bgcolor="#EFF1F1" class="newstop">
# <table border="0" cellpadding="0" cellspacing="1" class="shift" id="table_ob_nation">
# <tr>
# <td class="newstop" width="100px">原產地國別</td>
# <td class="newstop">
#
#
#
#
#
#
# 								中華民國(Republic of China (Taiwan))
# 								</td>
# </tr>
# <tr>
# <td class="newstop" valign="top">原產地國別<br/>得標金額</td>
# <td class="newstop">
#
#
#
#
#
#
# 									719,086元<br/>
# 									柒<span style="color:red">拾</span>壹萬玖仟零捌拾陸元
# 								</td>
# </tr>
# <tr>
# <td class="newstop" colspan="2"><hr/></td>
# </tr>
# </table>
# </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　未得標廠商1</th>
# <td bgcolor="#EFF1F1" class="newstop"></td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　　未得標廠商</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
# 				東軒盟企業有限公司
# 			</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　　是否合格</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
#
#
#
# 			是
# 			</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　　標價金額</th>
# <td bgcolor="#EFF1F1" class="newstop">
# 			781,460
# 			元</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　　未得標原因</th>
# <td bgcolor="#EFF1F1" class="newstop">
# 	                        資格、規格合於招標文件但非最低(高)標
#
#
# 			</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　　標價偏低理由</th>
# <td bgcolor="#EFF1F1" class="newstop">
# </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　未得標廠商2</th>
# <td bgcolor="#EFF1F1" class="newstop"></td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　　未得標廠商</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
# 				正東電器有限公司
# 			</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　　是否合格</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
#
#
#
# 			是
# 			</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　　標價金額</th>
# <td bgcolor="#EFF1F1" class="newstop">
# 			786,000
# 			元</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　　未得標原因</th>
# <td bgcolor="#EFF1F1" class="newstop">
# 	                        資格、規格合於招標文件但非最低(高)標
#
#
# 			</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　　標價偏低理由</th>
# <td bgcolor="#EFF1F1" class="newstop">
# </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　未得標廠商3</th>
# <td bgcolor="#EFF1F1" class="newstop"></td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　　未得標廠商</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
# 				建丞空調工程股份有限公司
# 			</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　　是否合格</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
#
#
#
# 			是
# 			</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　　標價金額</th>
# <td bgcolor="#EFF1F1" class="newstop">
# 			798,000
# 			元</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　　未得標原因</th>
# <td bgcolor="#EFF1F1" class="newstop">
# 	                        資格、規格合於招標文件但非最低(高)標
#
#
# 			</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　　標價偏低理由</th>
# <td bgcolor="#EFF1F1" class="newstop">
# </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　未得標廠商4</th>
# <td bgcolor="#EFF1F1" class="newstop"></td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　　未得標廠商</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
# 				亨佳空調工程有限公司
# 			</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　　是否合格</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
#
#
#
# 			否
# 			</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　　標價金額</th>
# <td bgcolor="#EFF1F1" class="newstop">
# 			753,070
# 			元</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　　未得標原因</th>
# <td bgcolor="#EFF1F1" class="newstop">
# 	                        價格文件未附或不符合規定
#
#
# 			</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　　標價偏低理由</th>
# <td bgcolor="#EFF1F1" class="newstop">
# </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　未得標廠商5</th>
# <td bgcolor="#EFF1F1" class="newstop"></td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　　未得標廠商</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
# 				有序凍藏設備有限公司
# 			</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　　是否合格</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
#
#
#
# 			是
# 			</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　　標價金額</th>
# <td bgcolor="#EFF1F1" class="newstop">
# 			739,300
# 			元</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　　未得標原因</th>
# <td bgcolor="#EFF1F1" class="newstop">
# 	                        資格、規格合於招標文件但非最低(高)標
#
#
# 			</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　　標價偏低理由</th>
# <td bgcolor="#EFF1F1" class="newstop">
# </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　未得標廠商6</th>
# <td bgcolor="#EFF1F1" class="newstop"></td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　　未得標廠商</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
# 				大成電器行
# 			</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　　是否合格</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
#
#
#
# 			是
# 			</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　　標價金額</th>
# <td bgcolor="#EFF1F1" class="newstop">
# 			728,724
# 			元</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　　未得標原因</th>
# <td bgcolor="#EFF1F1" class="newstop">
# 	                        資格、規格合於招標文件但非最低(高)標
#
#
# 			</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　　標價偏低理由</th>
# <td bgcolor="#EFF1F1" class="newstop">
# </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　未得標廠商7</th>
# <td bgcolor="#EFF1F1" class="newstop"></td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　　未得標廠商</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
# 				亞瑞司商行
# 			</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　　是否合格</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
#
#
#
# 			否
# 			</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　　標價金額</th>
# <td bgcolor="#EFF1F1" class="newstop">
# 			766,500
# 			元</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　　未得標原因</th>
# <td bgcolor="#EFF1F1" class="newstop">
# 	                        資格文件未附或不符合規定
#
#
# 			</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　　標價偏低理由</th>
# <td bgcolor="#EFF1F1" class="newstop">
# </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　未得標廠商8</th>
# <td bgcolor="#EFF1F1" class="newstop"></td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　　未得標廠商</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
# 				磐固企業有限公司
# 			</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　　是否合格</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
#
#
#
# 			是
# 			</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　　標價金額</th>
# <td bgcolor="#EFF1F1" class="newstop">
# 			739,660
# 			元</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　　未得標原因</th>
# <td bgcolor="#EFF1F1" class="newstop">
# 	                        資格、規格合於招標文件但非最低(高)標
#
#
# 			</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　　標價偏低理由</th>
# <td bgcolor="#EFF1F1" class="newstop">
# </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　未得標廠商9</th>
# <td bgcolor="#EFF1F1" class="newstop"></td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　　未得標廠商</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
# 				竑偉企業有限公司
# 			</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　　是否合格</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
#
#
#
# 			是
# 			</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　　標價金額</th>
# <td bgcolor="#EFF1F1" class="newstop">
# 			727,400
# 			元</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　　未得標原因</th>
# <td bgcolor="#EFF1F1" class="newstop">
# 	                        資格、規格合於招標文件但非最低(高)標
#
#
# 			</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　　標價偏低理由</th>
# <td bgcolor="#EFF1F1" class="newstop">
# </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　未得標廠商10</th>
# <td bgcolor="#EFF1F1" class="newstop"></td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　　未得標廠商</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
# 				祥慶電氣工程有限公司
# 			</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　　是否合格</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
#
#
#
# 			是
# 			</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　　標價金額</th>
# <td bgcolor="#EFF1F1" class="newstop">
# 			779,000
# 			元</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　　未得標原因</th>
# <td bgcolor="#EFF1F1" class="newstop">
# 	                        資格、規格合於招標文件但非最低(高)標
#
#
# 			</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　　標價偏低理由</th>
# <td bgcolor="#EFF1F1" class="newstop">
# </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　未得標廠商11</th>
# <td bgcolor="#EFF1F1" class="newstop"></td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　　未得標廠商</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
# 				鍾鼎電業有限公司
# 			</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　　是否合格</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
#
#
#
# 			是
# 			</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　　標價金額</th>
# <td bgcolor="#EFF1F1" class="newstop">
# 			783,000
# 			元</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　　未得標原因</th>
# <td bgcolor="#EFF1F1" class="newstop">
# 	                        資格、規格合於招標文件但非最低(高)標
#
#
# 			</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　　標價偏低理由</th>
# <td bgcolor="#EFF1F1" class="newstop">
# </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　未得標廠商12</th>
# <td bgcolor="#EFF1F1" class="newstop"></td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　　未得標廠商</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
# 				三澤工程股份有限公司
# 			</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　　是否合格</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
#
#
#
# 			是
# 			</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　　標價金額</th>
# <td bgcolor="#EFF1F1" class="newstop">
# 			780,000
# 			元</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　　未得標原因</th>
# <td bgcolor="#EFF1F1" class="newstop">
# 	                        資格、規格合於招標文件但非最低(高)標
#
#
# 			</td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">　　標價偏低理由</th>
# <td bgcolor="#EFF1F1" class="newstop">
# </td>
# </tr>
# </table>
# </td></tr>
# <!-- delimiter 決標品項 End -->
# <!-- delimiter 最有利標 Start -->
# <!-- delimiter 最有利標 End -->
# <!-- delimiter 英文公告 Start -->
# <!-- delimiter 英文公告 End -->
# <!-- delimiter 決標資料 Start -->
# <tr class="award_table_tr_6">
# <td align="center" bgcolor="#c79961" class="form_head" rowspan="13" valign="middle" width="38">
# <span class="newstop">決<br/>標<br/>資<br/>料</span>
# </td>
# </tr>
# <tr class="award_table_tr_6">
# <th bgcolor="#ddc09e" class="T11b" width="200">決標公告序號</th>
# <td bgcolor="#EFF1F1" class="newstop">
# 			001
# 		</td>
# </tr>
# <tr class="award_table_tr_6">
# <th bgcolor="#ddc09e" class="T11b" width="200">決標日期</th>
# <td bgcolor="#EFF1F1" class="newstop">
# 			104/09/11
#
# 		</td>
# </tr>
# <tr class="award_table_tr_6">
# <th bgcolor="#ddc09e" class="T11b" width="200">決標公告日期</th>
# <td bgcolor="#EFF1F1" class="newstop">
# 	        104/09/15
# 	    </td>
# </tr>
# <tr class="award_table_tr_6">
# <th bgcolor="#ddc09e" class="T11b" width="200">是否刊登公報</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
#
#
#
# 			否
# 		</td>
# </tr>
# <tr class="award_table_tr_6">
# <th bgcolor="#ddc09e" class="T11b" width="200">底價金額</th>
# <td bgcolor="#EFF1F1" class="newstop">
# 				750,000元
# 			</td>
# </tr>
# <tr class="award_table_tr_6">
# <th bgcolor="#ddc09e" class="T11b" width="200">底價金額是否公開</th>
# <td bgcolor="#EFF1F1" class="newstop">
# 				是
#
# 	                       </td>
# </tr>
# <tr class="award_table_tr_6">
# <th bgcolor="#ddc09e" class="T11b" width="200">總決標金額</th>
# <td bgcolor="#EFF1F1" class="newstop">
# 		    719,086元
#
#
# 		</td>
# </tr>
# <tr class="award_table_tr_6">
# <th bgcolor="#ddc09e" class="T11b" width="200">總決標金額是否公開</th>
# <td bgcolor="#EFF1F1" class="newstop">
# 			是
#
# 		</td>
# </tr>
# <!-- 最低標標案才顯示是否依採購法第58條規定採次低標或次次低標決標 -->
# <tr class="award_table_tr_6">
# <th bgcolor="#ddc09e" class="T11b" width="200">契約是否訂有依物價指數調整價金規定</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
#
#
#
# 			否
# 		</td>
# </tr>
# <tr class="award_table_tr_6">
# <th bgcolor="#ddc09e" class="T11b" width="200">未列物價調整規定說明</th>
# <td bgcolor="#EFF1F1" class="newstop">
#                        財物案
#
#                     </td>
# </tr>
# <tr class="award_table_tr_6">
# <th bgcolor="#ddc09e" class="T11b" width="200">履約執行機關</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
# 			機關代碼：26674374<br>機關名稱：新北市立永和幼兒園
# 		</br></td>
# </tr>
# <tr class="award_table_tr_6">
# <th bgcolor="#ddc09e" class="T11b" width="200">附加說明</th>
# <td bgcolor="#EFF1F1" class="newstop">
# </td>
# </tr>
# <!-- delimiter 決標資料 End -->
# <!-- delimiter 撤銷公告 Start -->
# <!-- delimiter 撤銷公告 End -->
# </tbody>
# </table>
# </div>

# %%
f = open('bid_list.txt', 'r')
import time
from bs4 import BeautifulSoup
for ele in f.readlines():
    link = ele.strip()
    res = requests.get(link)
    soup = BeautifulSoup(res.text)
    printarea = soup.select('#printArea')[0]
    rear_substring = link.split("pkAtmMain=")[1]
    param = rear_substring.split("&tenderCaseNo=") 
    pkAtmMain= param[0] 
    caseno= param[1] 
    fname = 'gov/{0}_{1}.txt'.format(pkAtmMain,caseno )    
    f2 = open(fname, 'w')
    f2.write(printarea.prettify('utf-8'))
    f2.close()
    time.sleep(3)
f.close()

# %%
#
case_dic = {}
f = open ('bid_list.txt','r')
for line in f.readlines():
    rec = line.strip()
    caseno = rec.split('tenderCaseNo=')[1]
    if caseno not in case_dic:
        case_dic[caseno] = 1
    else:
        print caseno
f.close()
# Out:
# 1040728-1
# 10412
# 104018
# 10439
# 1040814
# 1040908
# 10412
# 1040831
# 1040908
# 1040828
# 1040831
# 104079
# 10405
# NC04049P043
# 1040901
# 104053
# 1040820
# 10414
# 1040903
# 1040828
# 1040903
# 104011
# 1040909
# 104010
# 104020
# 10406
# 104011
# 1040903
# 1040805
# 104011
# 1040826
# 104030
# 10410
# 104024
# 104001
# 1040801
# 1040824
# 1040824
# 104011
# 104010

# %%
from bs4 import BeautifulSoup as bs
from selenium import webdriver
wd = webdriver.Firefox()
import requests
headers = {
    'Accept':'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
'Accept-Encoding':'gzip, deflate, sdch',
'Accept-Language':'zh-TW,zh;q=0.8,en-US;q=0.6,en;q=0.4',
'Cache-Control':'max-age=0',
'Connection':'keep-alive',
'Cookie':'RI=0',
'Host':'www.comicvip.com',
'Referer':'http://www.comicvip.com/show/cool-103.html?ch=799-1',
'Upgrade-Insecure-Requests':'1',
'User-Agent':'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/45.0.2454.85 Safari/537.36' 
}
res = requests.get('http://www.comicvip.com/show/cool-103.html?ch=799-2',headers=headers)
res.encoding = 'big5'
soup=bs(res.text)
print soup
# Out:
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"><title>海賊王 1 - 799  海賊王漫畫線上觀看 無限動漫 8comic.com</title><link href="/css/global.css" rel="stylesheet" type="text/css"><meta content="free comic,online comic,free anime download,free cartoon download,海賊王,在線漫畫,線上觀看,免費漫畫,漫畫下載,漫畫圖片,動畫下載,動畫,漫畫,卡通,動漫無限" name="keywords"><meta content="海賊王免費漫畫線上觀看 - free online comic" name="description"><head></head>
# <script>if(document.location.href.toLowerCase().indexOf("best-manga-104.html?ch=618")>0) document.location.href="temp104.html?ch=618";</script>
# <table align="center" bgcolor="#000000" border="0" cellpadding="0" cellspacing="0" width="100%"><tr><td bgcolor="#000000" colspan="2" width="10%"><a href="/" target="_top"><img align="absmiddle" border="0" id="logo" name="logo" src="/images/logos.gif"/></a></td>
# <td style="background:url(/images/tbg.jpg);background-repeat:no-repeat;"><script src="/js/top.js"></script></td><td align="right" nowrap="nowrap" valign="bottom" width="10%"><a href="/msg"><img align="absmiddle" border="0" src="/msg/images/newmsg0.gif"/></a> <a class="w" href="/msg" id="Msg2">漫畫報錯 </a><img align="absmiddle/" border="0" src="/images/vline.gif"> <a class="w" href="/member/favourite.aspx">收藏夾整理</a> <img align="absmiddle/" border="0" src="/images/vline.gif"> <a class="w" href="/comic/u-1.html">每日更新漫畫列表</a> <img align="absmiddle/" border="0" src="/images/vline.gif"><a class="w" href="/comic/all.html">全站漫畫列表</a>  </img></img></img></td></tr><tr><td background="/images/menubg2.gif" bgcolor="#CCCCCC" colspan="4"><table align="center" border="0" cellpadding="0" cellspacing="0" width="100%"><tr align="center"><th height="40"> </th><td><a href="/comic/1-1.html">格鬥</a></td><th><img src="/images/l.gif"/></th><td><a href="/comic/6-1.html">冒險</a></td><th><img src="/images/l.gif"/></th><td><a href="/comic/5-1.html">警探</a></td><th><img src="/images/l.gif"/></th><td><a href="/comic/4-1.html">戰國</a></td><th><img src="/images/l.gif"/></th><td><a href="/comic/2-1.html">競技</a></td><th><img src="/images/l.gif"/></th><td><a href="/comic/16-1.html">亨飪</a></td><th><img src="/images/l.gif"/></th><td><a href="/comic/7-1.html">機械</a></td><th><img src="/images/l.gif"/></th><td><a href="/comic/22-1.html">科幻</a></td><th><img src="/images/l.gif"/></th><td><a href="/comic/3-1.html">魔法</a></td><th><img src="/images/l.gif"/></th><td><a href="/comic/8-1.html">妖魔</a></td><th><img src="/images/l.gif"/></th><td><a href="/comic/19-1.html">恐怖</a></td><th><img src="/images/l.gif"/></th><td><a href="/comic/21-1.html">職業</a></td><th><img src="/images/l.gif"/></th><td><a href="/comic/9-1.html">港產</a></td><th><img src="/images/l.gif"/></th><td><a href="/comic/11-1.html">少女</a></td><th><img src="/images/l.gif"/></th><td><a href="/comic/12-1.html">少男</a></td><th><img src="/images/l.gif"/></th><td><a href="/comic/15-1.html">超女</a></td><th><img src="/images/l.gif"/></th><td><a href="/comic/13-1.html">搞笑</a></td><th><img src="/images/l.gif"/></th><td><a href="/comic/14-1.html">校園</a></td><th><img src="/images/l.gif"/></th><td><a href="/comic/18-1.html">短篇</a></td><th><img src="/images/l.gif"/></th><td><a href="/comic/20-1.html">其他</a></td><th align="right"> </th></tr></table></td></tr></table><script src="/js/nview.js"></script><form action="#" id="Form1" method="post">
# <div class="aspNetHidden">
# <input id="__VIEWSTATE" name="__VIEWSTATE" type="hidden" value="/wEPDwUKLTMwMDQyMTI1NmRksmOdHDYdo09eoeFgIU99wK+xiy7MZASgFvsMBA0VztE="/>
# </div>
# <div class="aspNetHidden">
# <input id="__VIEWSTATEGENERATOR" name="__VIEWSTATEGENERATOR" type="hidden" value="3CB179A0"/>
# </div><table align="center" border="0" cellpadding="0" cellspacing="0" width="97%"><tr><td height="20" nowrap="nowrap" width="90%"><script src="/js/topview.js"></script></td></tr></table><table align="center" border="0" cellpadding="0" cellspacing="0" width="97%"><tr><td align="center"><table border="0" cellpadding="0" cellspacing="0" width="100%">
# <tr>
# <td height="10"></td>
# </tr>
# <tr>
# <td align="center">
# <script type="text/javascript"><!--
# google_ad_client = "ca-pub-4955475422456028";
# /* 8C_970X90 */
# google_ad_slot = "8296529878";
# google_ad_width = 970;
# google_ad_height = 90;
# //-->
# </script>
# <script src="//pagead2.googlesyndication.com/pagead/show_ads.js" type="text/javascript">
# </script>
# </td>
# </tr>
# </table>
# <table border="0" cellpadding="0" cellspacing="0" height="10" width="100%">
# <tr>
# <td></td>
# </tr>
# </table></td></tr></table><table align="center" background="/images/barc.gif" border="0" cellpadding="0" cellspacing="0" height="18" width="97%"><tr><td nowrap="nowrap" width="20%"><b> <font color="#EE3366"><img align="absmiddle" src="/images/barl.gif"/>正在觀看:[ 海賊王 <font id="lastchapter">799</font> ]</font></b></td><td align="left" nowrap="nowrap" width="10%"><a false;="" href="#" id="prevvol" onclick="pv();return"><font face="webdings">7</font> 上集: <font id="prevname"></font></a>  </td><td align="right" nowrap="nowrap" width="10%"><a false;="" href="#" id="prev" onclick="jp();return"><b><font color="blue">[ <font face="webdings">3</font> 上 頁 ]</font></b></a></td><td align="center" height="1%" id="nav" nowrap="nowrap" width="10%"><select id="pageindex" name="select" onchange="j(this.value)" style="font-size:10px;font-family:arial"></select></td><td align="left" nowrap="nowrap" width="10%"><a false;="" href="#" id="next" onclick="jn();return"><b><font color="blue">[ 下 頁<font face="webdings">4</font> ]</font></b></a></td><td align="right" nowrap="nowrap" width="10%"><a false;="" href="#" id="nextvol" onclick="nv();return">下集: <font id="nextname"></font><font face="webdings">8</font></a></td><td align="right" nowrap="nowrap" width="24%"><a class="red" false;="" href="#" id="lastvol" onclick="lv();return"><b>最新:[海賊王 799 ]<font color="#0099CC"></font></b></a><img align="absmiddle" src="/images/barr.gif"/></td> </tr></table><table align="center" border="0" cellpadding="0" cellspacing="0" width="97%"><tr><td align="center"><table border="0" cellpadding="0" cellspacing="0" height="2"><tr><td> </td></tr></table>
# <div class="sitemajidr" model="728x90" position="top"></div>
# <script src="http://ad.sitemaji.com/ysm_8comic.js" type="text/javascript"></script>
# <table border="0" cellpadding="0" cellspacing="0" height="10"><tr><td> </td></tr></table></td></tr></table><table align="center" border="0" cellpadding="0" cellspacing="0" id="TheTable" width="97%"><tr><td align="center"><img border="0" id="TheImg" name="TheImg"/></td></tr></table><table align="center" cellpadding="0" cellspacing="0" width="97%"><tr><td align="center" height="5"></td></tr><tr><td align="center"><div class="sitemajiad" model="728x90" position="bottom"></div>
# <script src="http://ad.sitemaji.com/ysm_8comic.js" type="text/javascript"></script>
# <table border="0" cellpadding="0" cellspacing="0" height="1"><tr><td> </td></tr></table></td></tr><tr><td align="center" height="15" id="prevnext2"><a false;="" href="#" id="prev2" onclick="jp();return" style="line-height:14px"><font color="blue"><b>[ 上 頁 ]</b></font></a>          <a false;="" href="#" id="next2" onclick="jn();return" style="line-height:14px"><font color="blue"><b>[ 下 頁 ]</b></font></a></td></tr><tr><td align="center"><table align="center" border="0" cellpadding="0" cellspacing="0" width="100%">
# <tr>
# <td height="4"></td>
# </tr>
# <tr>
# <td align="center">
# <script type="text/javascript"><!--
# google_ad_client = "ca-pub-4955475422456028";
# /* 8C_970X250 */
# google_ad_slot = "5343114118";
# google_ad_width = 970;
# google_ad_height = 250;
# //-->
# </script>
# <script src="//pagead2.googlesyndication.com/pagead/show_ads.js" type="text/javascript">
# </script>
# </td>
# </tr>
# </table>
# <br>
# <br>
# <br>
# <br>
# <br>
# </br></br></br></br></br></td></tr></table><table align="center" background="/images/barc.gif" border="0" cellpadding="0" cellspacing="0" width="97%"><tr><td><img align="absmiddle" src="/images/barl.gif"/></td><td align="right" nowrap="nowrap" width="5%"><b><font color="#EE3366"></font></b>鎖定比例：</td><td nowrap="nowrap" width="15%"><img align="absmiddle/" alt="實際大小" hand="" hspace="2" id="za" onclick="zoomaa(this)" src="/images/zooma.gif" style="CURSOR:"><img align="absmiddle/" hand="" hspace="4" id="zf" onclick="zoomff(this)" src="/images/zoomf.gif" style="CURSOR:"/></img></td><td align="center" height="1%" nowrap="nowrap" width="20%">按[<font color="#FF0000">a</font>] 100%顯示 按 [<font color="#FF0000">z</font>] 適應大小</td><td align="center" id="pagenum" nowrap="nowrap" width="20%"></td><td align="center" nowrap="nowrap" width="20%"><font color="#0066CC">[按空格:左右移動]</font> </td><td align="right" nowrap="nowrap" width="20%"> <a href="javascript:window.close();">[ 關閉 ]</a>   <a href="#"><img align="absmiddle" border="0" hspace="2" src="/images/top.gif"/></a></td><td align="right" nowrap="nowrap"><img align="absmiddle" src="/images/barr.gif"/></td></tr></table><script>var chs=799;var ti=103;var cs='...';eval(unescape('sp%28%29;'));</script><table align="center" border="0" cellpadding="5" cellspacing="0" width="97%"><tr><td height="1%" nowrap="nowrap" width="80%"><table align="center" border="0" cellpadding="4" cellspacing="0"><tr><td align="center"><script src="/js/bottom.js"></script></td></tr></table></td></tr></table><table align="center" border="0" cellpadding="0" cellspacing="0" style="margin-top:1px" width="100%"><tr><td bgcolor="#dddddd" height="1"></td></tr><tr align="center" bgcolor="#eeeeee" height="20"><td></td></tr><tr><td align="center" bgcolor="#eeeeee" height="60" nowrap="nowrap"><br><a href="http://www.2comic.com" target="_blank">動漫易</a> | <a href="http://www.6comic.com" target="_blank">溜溜動漫</a> | <a href="http://www.862.tw" target="_blank">862遊戲</a> | <a href="http://www.8book.com" target="_blank">無限小說</a> <br><br><font color="#BFBFBF">本站所有圖片均來自網路資源,並且免費提供,如有任何問題請與我們聯繫,確認後本站將會進行修正.</font></br></br></br></td></tr></table></form></meta></meta></link></meta><img height="1" src="http://ad.yieldmanager.com/pixel?id=1077990&amp;t=2" width="1"/><img height="1" src="http://extern.yahoo.com/b?s=1197365499" width="1"/>
