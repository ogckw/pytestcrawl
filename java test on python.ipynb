# %%
#lab 01 print and change line
print 'fuxk \noops'
# Out:
# fuxk
# oops

# %%
#lab 02 print and split and list and compine
a = 'weqweq dddd ddddaawaw'
ad = ''
print a.split()

print ad.join(a.split())

list(ad.join(a.split()))
# Out:
# ['weqweq', 'dddd', 'ddddaawaw']
# weqweqddddddddaawaw
# ['w',
#  'e',
#  'q',
#  'w',
#  'e',
#  'q',
#  'd',
#  'd',
#  'd',
#  'd',
#  'd',
#  'd',
#  'd',
#  'd',
#  'a',
#  'a',
#  'w',
#  'a',
#  'w']

# %%
#lab 03 split by strip
a = 'awd aw d'
a.strip().split()
# Out:
# ['awd', 'aw', 'd']

# %%
# Writing hello world into test.txt
fid = open('test.txt','w')
fid.write('hello\nworld\nfuxk you')
fid = open('test.txt', 'r')
fid.read()
fid.close()
#####

# %%
fid = open('test.txt','w')
fid.write('hello\nworld\nfuxk you')
fid = open('test.txt', 'r')
for line in fid:
    print line, # comma , for change one line
fid = open('test.txt', 'r')
# Out:
# hello
# world
# fuxk you hello
#
# world
#
# fuxk you

# %%
# 讀取檔案內容 跳過空白行 fidreadlines()進的每一行(包括空白)視為一個完整狀態 除非讀如整個空白行才跳過
fid = open('E:\pg1104.txt', 'r')
for line in fid.readlines():
    print line.strip()
fid.close()
# Out:
# ﻿This Etext file is presented by Project Gutenberg, in
# cooperation with World Library, Inc., from their Library of the
# Future and Shakespeare CDROMS.  Project Gutenberg often releases
# Etexts that are NOT placed in the Public Domain!!
#
# *This Etext has certain copyright implications you should read!*
#
# <<THIS ELECTRONIC VERSION OF THE COMPLETE WORKS OF WILLIAM
# SHAKESPEARE IS COPYRIGHT 1990-1993 BY WORLD LIBRARY, INC., AND IS
# PROVIDED BY PROJECT GUTENBERG WITH PERMISSION.  ELECTRONIC AND
# MACHINE READABLE COPIES MAY BE DISTRIBUTED SO LONG AS SUCH COPIES
# (1) ARE FOR YOUR OR OTHERS PERSONAL USE ONLY, AND (2) ARE NOT
# DISTRIBUTED OR USED COMMERCIALLY.  PROHIBITED COMMERCIAL
# DISTRIBUTION INCLUDES BY ANY SERVICE THAT CHARGES FOR DOWNLOAD
# TIME OR FOR MEMBERSHIP.>>
#
# *Project Gutenberg is proud to cooperate with The World Library*
# in the presentation of The Complete Works of William Shakespeare
# for your reading for education and entertainment.  HOWEVER, THIS
# ...

# %%
## 讀取檔案內容 不跳過空白行 可與上下做對照
fid = open('E:\pg1104.txt', 'r')
for line in fid.readlines():
    print line
fid.close()
# Out:
# ﻿This Etext file is presented by Project Gutenberg, in
#
# cooperation with World Library, Inc., from their Library of the
#
# Future and Shakespeare CDROMS.  Project Gutenberg often releases
#
# Etexts that are NOT placed in the Public Domain!!
#
#
#
# *This Etext has certain copyright implications you should read!*
#
#
#
# <<THIS ELECTRONIC VERSION OF THE COMPLETE WORKS OF WILLIAM
#
# SHAKESPEARE IS COPYRIGHT 1990-1993 BY WORLD LIBRARY, INC., AND IS
#
# PROVIDED BY PROJECT GUTENBERG WITH PERMISSION.  ELECTRONIC AND
#
# MACHINE READABLE COPIES MAY BE DISTRIBUTED SO LONG AS SUCH COPIES
#
# (1) ARE FOR YOUR OR OTHERS PERSONAL USE ONLY, AND (2) ARE NOT
#
# DISTRIBUTED OR USED COMMERCIALLY.  PROHIBITED COMMERCIAL
#
# DISTRIBUTION INCLUDES BY ANY SERVICE THAT CHARGES FOR DOWNLOAD
#
# TIME OR FOR MEMBERSHIP.>>
#
#
#
# *Project Gutenberg is proud to cooperate with The World Library*
#
# in the presentation of The Complete Works of William Shakespeare
#
# ...

# %%
fid = open('E:\pg1104.txt', 'r')
for line in fid.readlines():
    ele= line.strip().split()
    print ele
fid.close()
# Out:
# ['\xef\xbb\xbfThis', 'Etext', 'file', 'is', 'presented', 'by', 'Project', 'Gutenberg,', 'in']
# ['cooperation', 'with', 'World', 'Library,', 'Inc.,', 'from', 'their', 'Library', 'of', 'the']
# ['Future', 'and', 'Shakespeare', 'CDROMS.', 'Project', 'Gutenberg', 'often', 'releases']
# ['Etexts', 'that', 'are', 'NOT', 'placed', 'in', 'the', 'Public', 'Domain!!']
# []
# ['*This', 'Etext', 'has', 'certain', 'copyright', 'implications', 'you', 'should', 'read!*']
# []
# ['<<THIS', 'ELECTRONIC', 'VERSION', 'OF', 'THE', 'COMPLETE', 'WORKS', 'OF', 'WILLIAM']
# ['SHAKESPEARE', 'IS', 'COPYRIGHT', '1990-1993', 'BY', 'WORLD', 'LIBRARY,', 'INC.,', 'AND', 'IS']
# ['PROVIDED', 'BY', 'PROJECT', 'GUTENBERG', 'WITH', 'PERMISSION.', 'ELECTRONIC', 'AND']
# ['MACHINE', 'READABLE', 'COPIES', 'MAY', 'BE', 'DISTRIBUTED', 'SO', 'LONG', 'AS', 'SUCH', 'COPIES']
# ['(1)', 'ARE', 'FOR', 'YOUR', 'OR', 'OTHERS', 'PERSONAL', 'USE', 'ONLY,', 'AND', '(2)', 'ARE', 'NOT']
# ...

# %%
##統計出現字
fid = open('E:\pg1104.txt', 'r')
dict = {}
for line in fid.readlines():
    ele = line.strip().split()
    for word in ele:
        if word in dict:
                dict[word] = dict[word]+1
        else:
            dict[word] = 1
fid.close()
count  = 0
for k,d in dict.item()
    print k,d,
# Out:
#   File "<ipython-input-2-a16635a21bd7>", line 13
#     for k,d in dict.item()
#                           ^
# SyntaxError: invalid syntax
