# %%
import requests
from bs4 import BeautifulSoup as bs
import jieba
headers = {
'Accept':'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
'Accept-Encoding':'gzip, deflate, sdch',
'Accept-Language':'zh-TW,zh;q=0.8,en-US;q=0.6,en;q=0.4',
'Connection':'keep-alive',
'Host':'news.ltn.com.tw',
'Referer':'http://news.ltn.com.tw/search',
'Upgrade-Insecure-Requests':'1',
'User-Agent':'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/45.0.2454.99 Safari/537.36' }
res = requests.get('http://news.ltn.com.tw/search?keyword=北投區&conditions=and&SYear=2015&SMonth=9&SDay=30&EYear=2015&EMonth=9&EDay=30',headers = headers)
soup = bs(res.content)
print soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <base href="http://news.ltn.com.tw">
# <meta charset="utf-8"/>
# <meta content="IE=10; IE=9; IE=8; IE=7" http-equiv="X-UA-Compatible"/>
# <title>搜尋結果 - 自由時報電子報</title>
# <meta content="sPp7Kk7Tqa6LK-wWblS9Fby069Wpy4DNTaMyjKHxveU" name="google-site-verification"/>
# <meta content="自由時報電子報" name="description">
# <meta content="自由時報, 自由電子報, 自由時報電子報, Liberty Times Net, LTN" name="keywords">
# <meta content="index,follow" name="robots"/>
# <meta content="140490219413038" property="fb:app_id">
# <meta content="自由時報電子報" property="og:title"/>
# <meta content="article" property="og:type"/>
# <meta content="http://news.ltn.com.tw" property="og:url"/>
# <meta content="自由時報電子報" property="og:description"/>
# <meta content="http://news.ltn.com.tw/images/all/250_ltn.png" property="og:image"/>
# <meta content="P" name="ltn:device"/>
# <link herf="http://news.ltn.com.tw/images/all/250_ltn.png" rel="image_src">
# <link href="http://news.ltn.com.tw" rel="canonical"/>
# <script src="//ajax.googleapis.com/ajax/libs/jquery/1.9.1/jquery.min.js" type="text/javascript"></script>
# <script>window.jQuery || document.write('<script src="/js/jquery/jquery-1.9.1.min.js"><\/script>')</script>
# <script>
# var mobileServer = 'm.ltn.com.tw',
# 	newsServer = 'news.ltn.com.tw',
# 	uri = '',
# 	category = '';
# </script>
# <!-- RTA Script TOP-->
# <script type="text/javascript">
#
# var crtg_nid = '4167';
# var crtg_cookiename = 'crtg_rta';
# var crtg_varname = 'crtg_content';
# function crtg_getCookie(c_name){ var i,x,y,ARRCookies=document.cookie.split(";");for(i=0;i<ARRCookies.length;i++){x=ARRCookies[i].substr(0,ARRCookies[i].indexOf("="));y=ARRCookies[i].substr(ARRCookies[i].indexOf("=")+1);x=x.replace(/^\s+|\s+$/g,"");if(x==c_name){return unescape(y);} }return'';}
# var crtg_content = crtg_getCookie(crtg_cookiename);
# var crtg_rnd=Math.floor(Math.random()*99999999999);
# (function(){
# 	var crtg_url=location.protocol+'//rtax.criteo.com/delivery/rta/rta.js?netId='+escape(crtg_nid);
# 	crtg_url +='&cookieName='+escape(crtg_cookiename);
# 	crtg_url +='&rnd='+crtg_rnd;
# 	crtg_url +='&varName=' + escape(crtg_varname);
# 	var crtg_script=document.createElement('script');crtg_script.type='text/javascript';crtg_script.src=crtg_url;crtg_script.async=true;
# 	if(document.getElementsByTagName("head").length>0)document.getElementsByTagName("head")[0].appendChild(crtg_script);
# 	else if(document.getElementsByTagName("body").length>0)document.getElementsByTagName("body")[0].appendChild(crtg_script);
# })();
#
# </script>
# <!--RTA Script END--><script src="/js/all.js?20150422" type="text/javascript"></script>
# <script src="/js/OneAD.js?20140731" type="text/javascript"></script>
# <script src="/js/jqcloud.min.js" type="text/javascript"></script>
# <script>
# var addate=new Array();
# var pagetype = 'other';
# addate['other'] = new Array();
# addate['other']['BD1']=['/21202031/01-news-other-BD1',[[300,250], [300,600]],'div-gpt-ad-1394733866591-0'];
# addate['other']['BD2']=['/21202031/01-news-other-BD2',[[300,250], [300,600]],'div-gpt-ad-1394733896102-0'];
# addate['other']['C1']=['/21202031/01-news-sponsors-B1', [300, 250], 'div-gpt-ad-1426068482679-0'];
# addate['other']['C2']=['/21202031/01-news-sponsors-B2', [300, 250], 'div-gpt-ad-1426068526813-0'];
# addate['other']['K1']=['/21202031/01-news-other-K1', [[970, 90], [970, 160], [970, 250]], 'div-gpt-ad-1419407017061-0'];
# </script><link href="/css/news/style.css?20150915" rel="stylesheet">
# <link href="/css/all/layout.css?20150312002" rel="stylesheet">
# <link href="/css/news/imatches.css" rel="stylesheet">
# <link href="/css/jqcloud.min.css" rel="stylesheet">
# <link href="/images/all/ltn.png" rel="apple-touch-icon"/>
# <link href="/images/all/ltn.png" rel="apple-touch-icon-precomposed"/>
# <link href="http://news.ltn.com.tw/images/all/favicon.ico" rel="shortcut icon"/>
# <script src="/js/GoogleDFP.js?20150720" type="text/javascript"></script>
# </link></link></link></link></link></meta></meta></meta></base></head>
# <body>
# <script type="text/javascript">
# 	/* yahoo ads */
# 	var sectionCode = sectionCode || [];
# 	sectionCode.push("05369588-41a4-4546-957c-f47cf466b75b", "94407ec6-524b-4986-b07f-32f1998e3267");
#
# 	(function(){
# 		/*show news content page only*/
# 		if(!(/^\/news\//).test(location.pathname)){return;}
# 		var script = document.createElement("script");
# 		script.async = true;
# 		script.src = "https://s.yimg.com/av/gemini/ga/gemini.js";
# 		document.body.appendChild(script);
# 	})();
# </script>
# <script type="text/javascript">
# _atrk_opts = { atrk_acct:"LS4hj1a8Dy002+", domain:"ltn.com.tw",dynamic: true};
# (function() { var as = document.createElement('script'); as.type = 'text/javascript'; as.async = true; as.src = "https://d31qbv1cthcecs.cloudfront.net/atrk.js"; var s = document.getElementsByTagName('script')[0];s.parentNode.insertBefore(as, s); })();
# var _comscore = _comscore || [];
# _comscore.push({ c1: "2", c2: "18368781" });
# (function() {
#   var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#   s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#   el.parentNode.insertBefore(s, el);
# })();
# </script>
# <noscript><img alt="" height="1" src="https://d5nxst8fruw4z.cloudfront.net/atrk.gif?account=LS4hj1a8Dy002+" style="display:none" width="1"/><img src="http://b.scorecardresearch.com/p?c1=2&amp;c2=18368781&amp;cv=2.0&amp;cj=1"/></noscript>
# <span class="page-name" data-desc="搜尋頁"></span>
# <div class="door-top-over-amg-open" style="display:none;">
# <div id="door-top-over-main" style="display:none;"></div>
# </div>
# <div id="door-top-over" style="display:none;">
# <div class="door-top-close"></div>
# </div>
# <div id="door-home-over" style="display:none;">
# <div class="door-home-close"></div>
# </div><div id="main">
# <!--//door top//-->
# <script type="text/javascript">
# <!--//
#
# (function(){
#
#
# 	var OneMinute = 1000 * 60;
# 	var OneHour = 60 * OneMinute;
# 	var OneDay = 24 * OneHour;
#
# 	var OnTime = function(y, m ,d){
# 		var now=new Date();
# 		var dt1=new Date(y, (m-0)*1-1, d, 12);
# 		var dt2=new Date();
# 		dt2.setTime(dt1.getTime() + OneDay);
#
# 		return (now>=dt1 && now<dt2) ? true : false;
#
# 	}
#
#     googletag.cmd.push(function () {
#
# 		var IsFireFox = false;
# 		if (navigator.userAgent.indexOf('Firefox')>=0){IsFireFox=true;}
# 		if(IsFireFox){$('.door-left-head, .door-right-head').height(130);}
#
#
# 		$('.door-top-close').on('click.close', function(e){
# 			$('#door-top-over').hide();
# 		});
#
# 		$('.door-home-close').on('click.close', function(e){
# 			$('#door-home-over').hide();
# 		});
#
# 		var S = 0;
# 		//var S1 = googletag.defineSlot('/21202031/AMG-SpecialProject', [[450, 250], [600, 330], [730, 575], [640, 360], [640, 480]], 'door-top-over').addService(googletag.pubads());
# 		//var S2 = googletag.defineSlot('/21202031/01-news-cover-800x600', [800, 600], 'door-home-over').addService(googletag.pubads());
# 		//var S3 = googletag.defineSlot('/21202031/AMG-overlay-code', [300, 100], 'door-top-over-main').addService(googletag.pubads());
#
# 		/*門簾*/
# 		var D = 0;
#
# 		var D1 = googletag.defineSlot('/21202031/01-ltn-news-doorcurtain-left', [150, 600], 'door-left').addService(googletag.pubads());
# 		var D2 = googletag.defineSlot('/21202031/01-ltn-news-doorcurtain-right', [150, 600], 'door-right').addService(googletag.pubads());
#
# 		googletag.pubads().addEventListener('slotRenderEnded', function(event) {
# 			if (event.isEmpty) { return; }
# 			if (event.slot === S1) {
# 				var w = parseInt($('#door-top-over > div > iframe').width(),10);
# 				$('.door-top-close').css('margin-left',(w-56*2)/2);
# 			}
#
# 			if (event.slot === S2) {
# 				var w = parseInt($('#door-home-over > div > iframe').width(),10);
# 				$('.door-home-close').css('margin-left',(w-86*2)/2);
# 			}
#
# 		});
#
# 		/*RTA Script TOP*/
# 		var crtg_split = (crtg_content || '').split(';');
# 		var pubads = googletag.pubads();
# 		for (var i=1;i<crtg_split.length;i++){
# 			pubads.setTargeting("" + (crtg_split[i-1].split('='))[0] + "", "" + (crtg_split[i-1].split('='))[1] + "");
# 		}
# 		/*RTA Script END*/
#
#         googletag.enableServices();
#     });
#
#     $(document).ready(function () {
#         googletag.cmd.push(function () {
# 			if(OnTime(2015, 9, 23) ){
# 				googletag.display('door-left');
# 				googletag.display('door-right');
# 			}
# 			googletag.display('door-top-over');
# 			googletag.display('door-top-over-main');
#
#         });
#     });
#
# })();
#
# //-->
# </script>
# <style>
#
# #door-full {
# 	position: relative;
# 	width: 970px;
#
# }
# #door-full-fix {
# 	width: 970px;
# 	position: fixed;
# 	z-index:9999;
#
# }
# .door-full-mid {
# 	width: 980px;
# 	height: 150px;
# 	margin-left: -5px;
# }
#
# .door-full-left {
# 	position: absolute;
# 	left: -155px;
# 	height: 750px;
# 	margin-top: -150px;
# }
#
# .door-full-right {
# 	position: absolute;
# 	right: -155px;
# 	height: 750px;
# 	margin-top: -150px;
# }
#
# #door-full-fix-head{
# 	height: 150px;
# }
#
# #door {
# 	position: relative;
# 	width: 970px;
# 	top: 124px;
# }
# #door-left {
# 	position: absolute;
# 	left: -155px;
# 	height: 600px;
# }
#
# #door-right {
# 	position: absolute;
# 	right: -155px;
# 	height: 600px;
# }
# .door-right-head, .door-left-head{
# 	width: 155px;
# 	height: 128px;
# 	background-color: white;
# 	margin-top: -169px;
# 	margin-left: -5px;
# 	margin-bottom: 5px;
# 	border-bottom: 41px solid #2360a3;
# }
#
# .door-left-head{
# 	margin-left: 0px;
# }
#
# #door-top-over, #door-home-over, .door-top-over-amg-open {
# 	position: fixed;
# 	z-index: 4001;
# 	background-color: rgba(0, 0, 0, 0.5);
# 	height: 120%;
# 	width: 100%;
# 	text-align: center;
# 	padding-top: 95px;
# }
#
# .door-top-close, .door-home-close {
# 	position:absolute;
# 	display:block;
# 	top: 0px;
# 	left: 50%;
# 	width:36px; height:36px;
# 	background:url(http://news.ltn.com.tw/images/news/bt-x.png) top center no-repeat;
# 	background-size: 36px 36px;
# 	cursor:pointer;
# 	z-index: 10999999;
# 	margin-left: 400px;
# 	margin-top: 95px;
# 	padding: 0 20px 20px 0px;
# }
#
# .door-home-close{
# 	width:86px;
# 	height:86px;
# 	padding: 0 0 0 0;
# }
#
#
# </style>
# <div id="door">
# <div id="door-left" style="display: none;">
# <div class="door-left-head"></div>
# </div>
# <div id="door-right" style="display: none;">
# <div class="door-right-head"></div>
# </div>
# </div>
# <div id="door-full">
# <div class="door-full-mid" id="door-full-mid" style="display: none;"></div>
# <div class="door-full-left" id="door-full-left" style="display: none;"></div>
# <div class="door-full-right" id="door-full-right" style="display: none;"></div>
# </div>
# <div id="door-full-fix">
# <div class="door-full-mid" id="door-full-fix-mid" style="display: none;"></div>
# <div class="door-full-left" id="door-full-fix-left" style="display: none;"></div>
# <div class="door-full-right" id="door-full-fix-right" style="display: none;"></div>
# </div>
# <div id="door-full-fix-head" style="display: none;"></div>
# <!--//door end//--><div class="header">
# <div class="top boxTitle" data-desc="頻道">
# | <a data-desc="設為首頁" href="#" onclick="this.style.behavior='url(#default#homepage)';this.setHomePage('http://www.ltn.com.tw/');">設為首頁</a> | <a data-desc="TAIPEI TIMES" href="http://www.taipeitimes.com/News" target="_blank">TAIPEI TIMES</a> | <a data-desc="yes123" href="http://www.yes123.com.tw/admin/index.asp" target="_blank">yes123求職網</a> | <a data-desc="爆料投訴" href="http://opinion.ltn.com.tw/inform/news.php">爆料投訴</a> | <a data-desc="廣告" href="http://news.ltn.com.tw/service?p=5">廣告</a> | <a data-desc="手機版" id="tom"><img align="absmiddle" height="15" src="http://news.ltn.com.tw/images/all/mobi.png"> 手機版</img></a> |</div>
# <div class="logo boxTitle" data-desc="頻道"><a data-desc="自由時報" href="http://www.ltn.com.tw/"><img alt="自由時報" src="/images/news/logo.jpg" title="自由時報"/></a></div>
# <div class="menu boxTitle" data-desc="頻道"><ul>
# <li><a data-desc="sports" href="http://sports.ltn.com.tw/"><img alt="自由體育" height="21" src="images/all/logo_sports.png" title="自由體育"/></a></li>
# <li><a data-desc="ent" href="http://ent.ltn.com.tw/"><img alt="自由娛樂" height="20" src="http://news.ltn.com.tw/images/all/h20_ent.png" title="自由娛樂"/></a></li>
# <li><a data-desc="talk" href="http://talk.ltn.com.tw/"><img alt="自由評論網" height="18" src="http://news.ltn.com.tw/images/all/h20_talk.png" title="自由評論網"/></a></li>
# <li><a data-desc="istyle" href="http://istyle.ltn.com.tw//"><img alt="iStyle頻道" height="33" src="http://news.ltn.com.tw/images/all/h47_istyle.png" title="iStyle頻道"/></a></li>
# <li><a data-desc="3c" href="http://3c.ltn.com.tw/"><img alt="3c頻道" height="19" src="http://news.ltn.com.tw/images/all/3c_logo.png" title="3c頻道"/></a></li>
# <li><a data-desc="auto" href="http://auto.ltn.com.tw/"><img alt="汽車頻道" height="19" src="http://news.ltn.com.tw/images/all/auto_logo.png" title="汽車頻道"/></a></li>
# <li><a data-desc="fun" href="http://fun.ltn.com.tw/"><img alt="自由fun送台" height="19" src="http://news.ltn.com.tw/images/all/fun_logo.png" title="自由fun送台"/></a></li>
# <li><a data-desc="week" href="http://week.ltn.com.tw/"><img alt="週報網頁版" height="19" src="http://news.ltn.com.tw/images/all/h20_weekender.png" title="週報網頁版"/></a></li>
# </ul></div>
# <div class="mtab boxTitle boxText" data-desc="選單"><ul id="mtabul">
# <li><a data-desc="即時" href="/list/BreakingNews">即時</a></li>
# <li><a data-desc="報紙" href="/newspaper">報紙</a></li>
# <li><a data-desc="焦點" href="/section/focus">焦點</a></li>
# <li><a data-desc="政治" href="/section/politics">政治</a></li>
# <li><a data-desc="社會" href="/section/society">社會</a></li>
# <li><a data-desc="地方" href="/section/local">地方</a></li>
# <li><a data-desc="生活" href="/section/life">生活</a></li>
# <li><a data-desc="言論" href="http://talk.ltn.com.tw">言論</a></li>
# <li><a data-desc="國際" href="/section/world">國際</a></li>
# <li><a data-desc="財經" href="/section/business">財經</a></li>
# <li><a data-desc="體育" href="http://sports.ltn.com.tw">體育</a></li>
# <li><a data-desc="娛樂" href="http://ent.ltn.com.tw">娛樂</a></li>
# <li><a data-desc="消費" href="/section/consumer">消費</a></li>
# <li><a data-desc="副刊" href="/section/supplement">副刊</a></li>
# <li><a data-desc="video" href="http://video.ltn.com.tw/">video</a></li>
# </ul>
# <script>
#   $("#mtabul li a:contains('搜尋結果')").attr('class','now2');
# </script>
# </div>
# <div class="ad970"><div id="ad-K1" style="display:none;"></div></div>
# </div>
# <div class="content">
# <script src="/js/extra.js?20150715" type="text/javascript"></script>
# <div class="guide boxTitle" data-desc="麵包屑"> <a data-desc="首頁" href="http://news.ltn.com.tw">首頁</a> &gt; <a data-desc="搜尋結果" href="/list/">搜尋結果</a></div>
# <div class="list">
# <div class="tit">查詢結果　共有 1 筆新聞</div>
# <div class="keyword"><form action="" method="GET" name="form1">關鍵字：<input id="keyword" maxlength="60" name="keyword" size="40" type="text" value="士林區">　<input checked="checked" name="conditions" type="radio" value="and"> AND / <input name="conditions" type="radio" value="or">OR
#   <br/>　　　　（最多三組關鍵字）<br/><br/>日期：<select id="SYear" name="SYear" onchange="changeDay('S')"></select> 年 <select id="SMonth" name="SMonth" onchange="changeDay('S')"> </select> 月 <select id="SDay" name="SDay"></select> 日 ～ <select id="EYear" name="EYear" onchange="changeDay('E')"></select> 年 <select id="EMonth" name="EMonth" onchange="changeDay('E')"></select> 月 <select id="EDay" name="EDay"></select> 日
#   <br/>（每次查詢區間最長為三個月，例：2005 年 1 月 1 日 ～ 2005 年 3 月 31 日）<br/><div><input onclick="send()" type="button" value="查詢"/></div></input></input></input></form></div>
# <script>
#   o = document.form1
#   var d = new Date()
#   var ys = 2005
#   var ye = d.getFullYear()
#   var mm = new Array(31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31)
#   function init (){
#     // 建立年 options
#     o.SYear.options.length = ye - ys + 1
#     for (var i = ys, j = 0; i <= ye; i++, j++) {
#       o.SYear.options[j].value = i
#       o.SYear.options[j].text  = i
#       if (o.SYear.options[j].value == 2015)
#         o.SYear.selectedIndex = j;
#     }
#     // 建立月 options
#     o.SMonth.options.length = 12
#     for (var i = 1, j = 0; i <=12; i++, j++) {
#       o.SMonth.options[j].value = i
#       o.SMonth.options[j].text  = i
#       if (o.SMonth.options[j].value == 9)
#         o.SMonth.selectedIndex = j;
#     }
#
#     // 建立日 預設一月
#     o.SDay.options.length = 31
#     for (var i = 1, j = 0; i <= mm[0]; i++, j++) {
#       o.SDay.options[j].value = i
#       o.SDay.options[j].text  = i
#       if (o.SDay.options[j].value == 30)
#         o.SDay.selectedIndex = j;
#     }
#   }
#   function init1 (){
#     // 建立年 options
#     o.EYear.options.length = ye - ys + 1
#     for (var i = ys, j = 0; i <= ye; i++, j++) {
#       o.EYear.options[j].value = i
#       o.EYear.options[j].text  = i
#       if (o.EYear.options[j].value == 2015)
#         o.EYear.selectedIndex = j;
#     }
#     // 建立月 options
#     o.EMonth.options.length = 12
#     for (var i = 1, j = 0; i <=12; i++, j++) {
#       o.EMonth.options[j].value = i
#       o.EMonth.options[j].text  = i
#       if (o.EMonth.options[j].value == 9)
#         o.EMonth.selectedIndex = j;
#     }
#
#     // 建立日 預設一月
#     o.EDay.options.length = 31
#     for (var i = 1, j = 0; i <= mm[0]; i++, j++) {
#       o.EDay.options[j].value = i
#       o.EDay.options[j].text  = i
#       if (o.EDay.options[j].value == 30)
#         o.EDay.selectedIndex = j;
#     }
#   }
#
#   function changeDay (p)
#   {
#     if(p == 'S'){
#       year  = o.SYear.options[o.SYear.selectedIndex].value
#       month = o.SMonth.options[o.SMonth.selectedIndex].value
#     }
#     else if(p == 'E'){
#       year  = o.EYear.options[o.EYear.selectedIndex].value
#       month = o.EMonth.options[o.EMonth.selectedIndex].value
#     }
#     // 處理二月份
#     if (month == 2) { // 口訣:四年一潤，百年不潤，四百年潤。
#       day = ((year%4 == 0) && ((year%100 != 0) || (year%400 == 0))) ? 29 : mm[1]
#     }
#     else {
#       day = mm[month-1]
#     }
#
#     // 建立日
#     if(p == 'S'){
#       o.SDay.options.length = day
#       for (var i = 1, j = 0; i <= day; i++, j++) {
#         o.SDay.options[j].value = i
#         o.SDay.options[j].text  = i
#       }
#     }
#     else if(p == 'E'){
#       o.EDay.options.length = day
#       for (var i = 1, j = 0; i <= day; i++, j++) {
#         o.EDay.options[j].value = i
#         o.EDay.options[j].text  = i
#       }
#     }
#   }
#
#   init ();
#   init1 ();
#
#   var count = 0;
#   function send(){
#   if (count == 0){
#     count++;
#   key = document.getElementById("keyword").value.replace(/(　)+/g, ' ');
#   key = key.replace(/( )+/g, ' ');
#   key = key.replace(/^[\s]*/gi,""); //去除左邊空白
#   key = key.replace(/[\s]*$/gi,""); //去除右邊空白
#   document.getElementById("keyword").value = key;
#   kw = key.split(" ");
#   sd = new Date(document.getElementById("SYear").value, document.getElementById("SMonth").value, document.getElementById("SDay").value);
#   ed = new Date(document.getElementById("EYear").value, document.getElementById("EMonth").value, document.getElementById("EDay").value);
#   sum = ed.getTime() - sd.getTime();
#   sum = sum/(24*60*60*1000);
#   dateok = 0;
#   if(ed.getYear() - sd.getYear() == 0){
#     if(ed.getMonth() - sd.getMonth() < 3)
#       dateok = 1;
#     else if(ed.getMonth() - sd.getMonth() > 3)
#       dateok = 0;
#     else{
#       if(ed.getDate() - sd.getDate() <= 0)
#         dateok = 1;
#       else
#         dateok = 0;
#     }
#   }
#   else if(ed.getYear() - sd.getYear() == 1){
#     if(sd.getMonth() > 12-(3-ed.getMonth()))
#       dateok = 1;
#     else if(sd.getMonth() < 12-(3-ed.getMonth()))
#       dateok = 0;
#     else{
#       if(ed.getDate() - sd.getDate() <= 0)
#         dateok = 1;
#       else
#         dateok = 0;
#     }
#   }
#   if(key.length > 50){
#     alert("關鍵字數過長");
#     count = 0;
#   }
#   else if(kw.length > 3){
#     alert("超過三組關鍵字");
#     count = 0;
#   }
#   else if((kw.length == 1 && kw[0].length < 2)){
#     alert("關鍵字需兩個字以上");
#     count = 0;
#   }
#   else if(sum < 0){
#     alert("查詢區間有誤");
#     count = 0;
#   }
# 	else if(dateok == 0){
# 		alert("查詢區間超過三個月");
# 		count = 0;
# 	}
# 	else
# 		o.submit();
# 	}
# }
#   </script>
# <div id="adcontainer1" style="margin:30px auto;"></div>
# <script src="http://www.google.com/adsense/search/ads.js" type="text/javascript"></script>
# <script charset="utf-8" type="text/javascript">
#   var pageOptions = {
#     'pubId' : 'pub-2766208854826292',
#     'query' : '士林區',
#     'channel' : '5965750859'
#   };
#
#   var adblock1 = {
#     'container': 'adcontainer1',
#     'width' : '550px',
#     'lines': '3',
#     'fontSizeTitle': '15px',
#     'colorTitleLink': '044E8C',
#     'colorText': '303030',
#     'colorDomainLink': '029EF7'
#   };
#
#   new google.ads.search.Ads(pageOptions, adblock1);
#   </script>
# <div>
# <script>
#
#   (function() {
#     var cx = '009486157720248261890:hvdfrxsipb0';
#     var gcse = document.createElement('script');
#     gcse.type = 'text/javascript';
#     gcse.async = true;
#     gcse.src = (document.location.protocol == 'https:' ? 'https:' : 'http:') +
#         '//www.google.com/cse/cse.js?cx=' + cx;
#     var s = document.getElementsByTagName('script')[0];
#     s.parentNode.insertBefore(gcse, s);
#   })();
#
# </script>
# </div>
# <ul class="boxTitle" data-desc="列表" id="newslistul">
# <li><span>2015-09-30   12:36</span><img src="/images/list/tab4.gif"/><a data-desc="標題" href="/news/life/breakingnews/1460781">停水超過40小時掀民怨 北水處：加開臨時取水站</a><div class="search">部分地區停水時間超過30小時，管線末端用戶復水不及，已緊急加開臨時取水站供民眾取水。
#
# 　<strong>士林區</strong>民游小姐說，她早上六點興沖沖打開水龍頭，卻一滴水也沒有，等了一小時仍未來水，令人憤怒；北投區民林...</div></li>
# </ul>
# </div>
# <div class="boxTitle boxText" data-desc="分頁" id="page"><span class="p_first">第一頁</span><strong class="p_num">1</strong><span class="p_last">最後</span></div>
class="col boxTitle" data-desc="中英">
# <div class="subjtit"><a data-desc="中英對照" href="http://iservice.ltn.com.tw/Service/english/">中英對照讀新聞</a><div class="more" style="font-size:0.98em"><a data-desc="more" href="http://iservice.ltn.com.tw/Service/english/">更多中英新聞»</a></div></div>
# <ul class="colsubj">
# <a href="http://iservice.ltn.com.tw/Service/english/english.php?engno=915795&amp;day=2015-09-16"><li class="lia">Texas judge gives man a choice: get married or go to jail 德州法官讓男子選擇結婚或入獄</li></a>
# <a href="http://iservice.ltn.com.tw/Service/english/english.php?engno=660209&amp;day=2013-03-09"><li class="lia">Now wash your hands：They are much dirtier than you think 現在去洗手：它們比你想的骯髒多了</li></a>
# <a href="http://iservice.ltn.com.tw/Service/english/english.php?engno=644187&amp;day=2013-01-07"><li class="lia">It really gets my goat when I miss a great shot! 我錯過一個大好鏡頭真令我抓狂</li></a>
# </ul>
# </div>
# <div class="col boxTitle" data-desc="中英">
# <div class="subjtit"><a data-desc="中英對照" href="http://iservice.ltn.com.tw/Service/english/">中英對照讀新聞</a><div class="more" style="font-size:0.98em"><a data-desc="more" href="http://iservice.ltn.com.tw/Service/english/">更多中英新聞»</a></div></div>
# <ul class="colsubj">
# <a href="http://iservice.ltn.com.tw/Service/english/english.php?engno=915471&amp;day=2015-09-15"><li class="lia">Facebook sees a billion users in a single day 臉書發現單日內有10億名用戶
# <a href="http://iservice.ltn.com.tw/Service/english/english.php?engno=896322&amp;day=2015-07-09"><li class="lia">Chocolate may be good for your heart, study suggests 研究顯示，巧克力可能對心臟有益</li></a>
# <a href="http://iservice.ltn.com.tw/Service/english/english.php?engno=638147&amp;day=2012-12-14"><li class="lia">Lucky Norway family wins national lottery three times 幸運的挪威家庭簽中3次國家樂透</li></a>
# </li></a></ul>
# </div>
# <div class="col boxTitle" data-desc="中英">
# <div class="subjtit"><a data-desc="中英對照" href="http://iservice.ltn.com.tw/Service/english/">中英對照讀新聞</a><div class="more" style="font-size:0.98em"><a data-desc="more" href="http://iservice.ltn.com.tw/Service/english/">更多中英新聞»</a></div></div>
# <ul class="colsubj">
# <a href="http://iservice.ltn.com.tw/Service/english/english.php?engno=915192&amp;day=2015-09-14"><li class="lia">Comedian leads president vote in corruption-weary Guatemala 喜劇演員在厭倦貪污的瓜地馬拉總統選舉中領先</li></a>
# <a href="http://iservice.ltn.com.tw/Service/english/english.php?engno=891956&amp;day=2015-06-24"><li class="lia">Cat wins shelter's Hero Dog award for saving kid from canine 從犬口救出幼童，貓咪贏得動物庇護機構的英雄犬獎</li></a>
# <a href="http://iservice.ltn.com.tw/Service/english/english.php?engno=897627&amp;day=2015-07-14"><li class="lia">New blood test can reveal past viruses 新的血液檢測可以顯示過去的病毒</li></a>
# </ul>
# </div>
# <div class="col boxTitle" data-desc="中英">
# <div class="subjtit"><a data-desc="中英對照" href="http://iservice.ltn.com.tw/Service/english/">中英對照讀新聞</a><div class="more" style="font-size:0.98em"><a data-desc="more" href="http://iservice.ltn.com.tw/Service/english/">更多中英新聞»</a></div></div>
# <ul class="colsubj">
# <a href="http://iservice.ltn.com.tw/Service/english/english.php?engno=914981&amp;day=2015-09-13"><li class="lia">British girls vie for co-star chance in Harry Potter spin-off movie 英國女孩競爭哈利波特外傳電影合演機會</li></a>
# <a href="http://iservice.ltn.com.tw/Service/english/english.php?engno=655523&amp;day=2013-02-21"><li class="lia">Could an earlier lunchtime help you lose weight? 提早吃午餐有助減重？</li></a>
# <a href="http://iservice.ltn.com.tw/Service/english/english.php?engno=637583&amp;day=2012-12-12"><li class="lia">Urban sparrows find new use for cigarette butts 城市麻雀發現菸屁股新用處</li></a>
# </ul>
# </div>
# <div class="col boxTitle" data-desc="中英">
# <div class="subjtit"><a data-desc="中英對照" href="http://iservice.ltn.com.tw/Service/english/">中英對照讀新聞</a><div class="more" style="font-size:0.98em"><a data-desc="more" href="http://iservice.ltn.com.tw/Service/english/">更多中英新聞»</a></div></div>
# <ul class="colsubj">
# <a href="http://iservice.ltn.com.tw/Service/english/english.php?engno=914743&amp;day=2015-09-12"><li class="lia">Australian sheep is unofficially the world's woolliest 澳洲綿羊寫下最多羊毛非官方紀錄</li></a>
# <a href="http://iservice.ltn.com.tw/Service/english/english.php?engno=645737&amp;day=2013-01-12"><li class="lia">Watching horror films burns calories 看恐怖片能燃燒卡路里</li></a>
# <a href="http://iservice.ltn.com.tw/Service/english/english.php?engno=729386&amp;day=2013-11-11"><li class="lia">Sweets at supermarket tills are 'fuelling obesity crisis' 超市收銀台的糖果「助長肥胖危機」</li></a>
# </ul>
# </div></div>
# <script>
# $('.manPrt').each(function(){
# var mang = $('.col',this),x = $(mang[Math.floor(Math.random() * mang.size())]);
# x.addClass('manColOn');
# });
# </script>
# <div class="top boxTitle" data-desc="Top"><a data-desc="Top" href="#"><img alt="Top" src="/images/all/top.gif" title="Top"/></a></div>
# </div>
# <div class="adright">
# <div class="adright_bar">
# <div class="date"></div>
# <div class="ad_w300"><div id="ad-BD1"></div></div>
# <div class="search boxTitle" data-desc="新聞查詢">新聞查詢：<a data-desc="關鍵字" href="/search">關鍵字</a> | <a data-desc="昔日新聞" href="/newspaper">昔日新聞</a></div>
# <div class="boxTitle hottag" data-desc="熱門關鍵字"><strong>熱門關鍵字</strong>
# <div data-desc="熱門關鍵字" id="hot_keyword_area" style="width:300px;height:250px;diesplay:block;">
# </div>
# <script src="https://code.jquery.com/ui/1.11.4/jquery-ui.js"></script>
# <script type="text/javascript">
# 	$(document).ready(function() {
# 		window.setTimeout(function(){
# 	    	$('#hot_keyword_area').children().each(function() {
# 				if ( $(this).attr("class") == 'w10' ||
# 					$(this).attr("class") == 'w9' ||
# 					$(this).attr("class") == 'w8' ||
# 					$(this).attr("class") == 'w7' ||
# 					$(this).attr("class") == 'w6')
# 				{
# 					var colorbase = ["#e60017", "#8a541f", "#00791C", "#C56202", "#CB18BB","#000000"];
# 					var cols = [];
# 					cols = hotkeyword_shuffle(colorbase);
# 					var cPos = 0;
# 					swapC($(this), cols, cPos);
# 				}
# 			});
# 	    }, 500);
# 	});
#
# 	function swapC(dom, cols, cPos)
# 	{
# 	    var move_sec = ( Math.floor((Math.random() * 3) + 1) * 500 );
# 	    dom.animate(
# 	    	{
# 	    		color: cols[cPos]
# 	    	},
# 	    	500
# 	    );
#
# 	    cPos++;
# 	    if (cPos == cols.length)
# 	    {
# 	        cPos = 0;
# 	    }
# 	    window.setTimeout(function(){
# 	    	swapC(dom, cols, cPos);
# 	    }, move_sec);
# 	}
#
# 	function hotkeyword_shuffle(o)
# 	{
# 	    for(var j, x, i = o.length; i; j = Math.floor(Math.random() * i), x = o[--i], o[i] = o[j], o[j] = x);
# 	    return o;
# 	};
#
# 		var hot_keyword_words = [
#
# 						{text: '杜鵑颱風', weight: 19, link: '/topic/杜鵑颱風'},
# 						{text: '颱風', weight: 18, link: '/topic/颱風'},
# 						{text: '杜鵑', weight: 17, link: '/topic/杜鵑'},
# 						{text: '吳宗憲', weight: 16, link: '/topic/吳宗憲'},
# 						{text: '金鐘50', weight: 15, link: '/topic/金鐘50'},
# 						{text: '停班停課', weight: 14, link: '/topic/停班停課'},
# 						{text: '小S', weight: 13, link: '/topic/小S'},
# 						{text: '洪秀柱', weight: 12, link: '/topic/洪秀柱'},
# 						{text: '黃子佼', weight: 11, link: '/topic/黃子佼'},
# 						{text: '柯文哲', weight: 10, link: '/topic/柯文哲'},
# 						{text: '邦喬飛', weight: 9, link: '/topic/邦喬飛'},
# 						{text: '2015金鐘獎', weight: 8, link: '/topic/2015金鐘獎'},
# 						{text: '金鐘', weight: 7, link: '/topic/金鐘'},
# 						{text: '颱風假', weight: 6, link: '/topic/颱風假'},
# 						{text: 'Bigbang', weight: 5, link: '/topic/Bigbang'},
# 						{text: 'MLB', weight: 4, link: '/topic/MLB'},
# 						{text: '金鐘獎', weight: 4, link: '/topic/金鐘獎'},
# 						{text: '福山雅治', weight: 4, link: '/topic/福山雅治'},
# 						{text: '中秋節', weight: 4, link: '/topic/中秋節'},
# 						{text: '朱立倫', weight: 4, link: '/topic/朱立倫'},
# 						{text: ' BIGBANG', weight: 4, link: '/topic/ BIGBANG'},
# 						{text: '龍腦', weight: 4, link: '/topic/龍腦'},
# 						{text: '曾寶儀', weight: 4, link: '/topic/曾寶儀'},
# 						{text: '藍正龍', weight: 4, link: '/topic/藍正龍'},
# 						{text: '豆花妹', weight: 4, link: '/topic/豆花妹'},
# 						{text: '2016總統大選', weight: 4, link: '/topic/2016總統大選'},
# 						{text: '吳洛纓', weight: 4, link: '/topic/吳洛纓'},
# 						{text: '公車', weight: 4, link: '/topic/公車'},
# 						{text: '習近平', weight: 4, link: '/topic/習近平'},
# 						{text: 'SpeXial', weight: 4, link: '/topic/SpeXial'},
# 						{text: '木村拓哉', weight: 4, link: '/topic/木村拓哉'},
# 						{text: '2015', weight: 4, link: '/topic/2015'},
# 						{text: '中職', weight: 4, link: '/topic/中職'},
# 						{text: '國民黨', weight: 4, link: '/topic/國民黨'},
# 						{text: 'AT-3教練機', weight: 4, link: '/topic/AT-3教練機'},
# 						{text: '北北基', weight: 4, link: '/topic/北北基'},
# 						{text: '羅進光', weight: 4, link: '/topic/羅進光'},
# 						{text: '李全教', weight: 4, link: '/topic/李全教'},
# 						{text: '蔡英文', weight: 4, link: '/topic/蔡英文'},
#
# 		];
#
# 		$('#hot_keyword_area').jQCloud(
# 			hot_keyword_words,
# 			{
# 				colors: ["#e60017", "#8a541f", "#f69757", "#7acd8d", "#37b6d1", "#977BE4", "#888888"],
# 				delay : 1,
# 				center: {x:0.4,y:0.5},
# 				autoResize: true,
# 				shape: 'rectangular',
# 				fontSize: {
# 					from: 0.11,
# 					to: 0.04
# 				}
# 			}
# 		);
# 	</script>
# </div>
# <div class="pointnew boxTitle" data-desc="關注瀏覽Tab" id="pointnew">
# <ul class="tab" id="pointnewstab">
# <li class="pnt_focus"><a data-desc="網友關注" href="javascript:pointnewstab(0)">近期網友關注</a></li>
# <li><a data-desc="瀏覽記錄" href="javascript:pointnewstab(1)">瀏覽記錄</a></li>
# </ul>
# <div class="con boxTitle" data-desc="關注新聞" id="pointnews0">
# <ul>
# <li><div class="no">1</div><a href="/news/life/breakingnews/1458838">18縣市及高市3區 明（29）日停班停課</a></li>
# <li><div class="no">2</div><a href="/news/life/breakingnews/1460017">員山子分洪量破紀錄 網友推爆：阿扁德政！</a></li>
# <li><div class="no">3</div><a href="/news/entertainment/breakingnews/1458546">哭哭！黃子佼金鐘「求婚」 孟耿如直接打槍...</a></li>
# <li><div class="no">4</div><a href="/news/politics/breakingnews/1459403">北北基放假 惹禍及搶功都同一人…</a></li>
# <li><div class="no">5</div><a href="/news/entertainment/breakingnews/1458239">T.O.P被爆台灣有女友 GD褲子拉鍊沒拉</a></li>
# </ul>
# <span><a data-desc="ReadMore" href="/list/Highlights">更多關注新聞</a></span>
# </div>
# <div class="con2 boxTitle" data-desc="瀏覽記錄" id="pointnews1">
# <ul>
# </ul>
# </div>
# </div>
# <script>
# function pointnewstab(o){
#   $('#pointnewstab li').removeClass('pnt_focus');
#   $('#pointnewstab li:nth('+o+')').addClass('pnt_focus').children('a').blur();
#   $("#pointnew > div").hide();
#   $('#pointnew > div:nth('+o+')').show();
# }
# pointnewstab(0);
# </script>
# <style>
# .market300{width:300px;padding:0px;margin:10px 0px;letter-spacing:1px;clear:both;}
# .market300 strong{display:block;padding:3px 5px;margin-bottom:5px;background-color:#f7e1e3;}
# .market300 li{width:96%;line-height:20px;padding:5px 0px 5px 20px;list-style:none;background:url(http://news.ltn.com.tw/images/all/dot-light.gif) no-repeat 10px 13px;}
# .market300 a{color:#005184;}
# .market300 span{display:block;border-top:1px solid #dcdcdc;padding:2px 0px;font-size:13px;font-weight:bold;text-align:right;}
# </style>
# <ul class="market300">
# <strong>市場動態</strong>
# <span><a href="http://market.ltn.com.tw">更多市場動態 »</a></span>
# </ul><div class="ad_w300"><div id="ad-BD2"></div></div>
# <div class="ad_w300">
# <script>
# T = $(".ad_w300 .NC3");
# if (T.length>0){
#   $.each(T,function(){
#     ADRand = ADRandCeil(1,$("a",this).length)-1;
#     $("a:eq("+ADRand+")",this).show();
# 	var adno = $("a:eq("+ADRand+")",this).attr("href");
# 	var adnoArray = new Array();
# 	adnoArray = adno.split("=");
# 	var adpv = $( '<scr'+'ipt src="http://iservice.ltn.com.tw/IService2/ad2.php?ano='+adnoArray[1]+'" async></scr'+'ipt>');
# 	adpv.appendTo(this);
#     $("a",this).each(function(){
#       $(this).attr('href',$(this).attr('href')+'&source='+document.URL);
#     });
#   });
# }
# function ADRandCeil(min,max) {
#   return Math.ceil(Math.random()*(max-min+1)+min-1);
# }
# </script>
# </div><div class="fb-like-box" data-colorscheme="light" data-header="false" data-height="490" data-href="https://www.facebook.com/m.ltn.tw" data-show-border="true" data-show-faces="true" data-stream="true"></div>
# <div class="ad_w300">
# <script>
# T = $(".ad_w300 .NC1");
# if (T.length>0){
#   $.each(T,function(){
#     ADRand = ADRandCeil(1,$("a",this).length)-1;
#     $("a:eq("+ADRand+")",this).show();
# 	var adno = $("a:eq("+ADRand+")",this).attr("href");
# 	var adnoArray = new Array();
# 	adnoArray = adno.split("=");
# 	var adpv = $( '<scr'+'ipt src="http://iservice.ltn.com.tw/IService2/ad2.php?ano='+adnoArray[1]+'" async></scr'+'ipt>');
# 	adpv.appendTo(this);
#     $("a",this).each(function(){
#       $(this).attr('href',$(this).attr('href')+'&source='+document.URL);
#     });
#   });
# }
# function ADRandCeil(min,max) {
#   return Math.ceil(Math.random()*(max-min+1)+min-1);
# }
# </script>
# </div></div>
# </div>
# <div class="footer boxTitle" data-desc="底部選單">
# <a data-desc="自由時報" href="http://www.ltn.com.tw"><img alt="自由時報" src="/images/news/logo_foot.png" title="自由時報"/></a><br/>版權所有 不得轉載 © 2015 The Liberty Times. All Rights Reserved.
# </div>
# </div>
# </body></html>
# <!--[if lt IE 7 ]>
#     <script src="//ajax.googleapis.com/ajax/libs/chrome-frame/1.0.3/CFInstall.min.js"></script>
#     <script>window.attachEvent('onload',function(){CFInstall.check({mode:'overlay'})})</script>
# <![endif]-->
